# %%
pip install numpy librosa pretty_midi matplotlib torch tqdm soundfile pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -rotobuf (/nfsshare/selva/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/nfsshare/selva/.local/lib/python3.9/site-packages)
# Requirement already satisfied: numpy in ./.local/lib/python3.9/site-packages (1.21.0)
# Requirement already satisfied: librosa in ./.local/lib/python3.9/site-packages (0.10.2.post1)
# Requirement already satisfied: pretty_midi in ./.local/lib/python3.9/site-packages (0.2.10)
# Requirement already satisfied: matplotlib in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (3.6.2)
# Requirement already satisfied: torch in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (1.12.0)
# Requirement already satisfied: tqdm in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (4.64.1)
# Requirement already satisfied: soundfile in ./.local/lib/python3.9/site-packages (0.13.1)
# Requirement already satisfied: pandas in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (1.4.4)
# Requirement already satisfied: lazy-loader>=0.1 in ./.local/lib/python3.9/site-packages (from librosa) (0.4)
# Requirement already satisfied: scipy>=1.2.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from librosa) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from librosa) (1.4.0)
# Requirement already satisfied: pooch>=1.1 in ./.local/lib/python3.9/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in ./.local/lib/python3.9/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: decorator>=4.3.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: joblib>=0.14 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from librosa) (1.3.2)
# Requirement already satisfied: typing-extensions>=4.1.1 in ./.local/lib/python3.9/site-packages (from librosa) (4.12.2)
# Requirement already satisfied: msgpack>=1.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: numba>=0.51.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from librosa) (0.55.1)
# Requirement already satisfied: audioread>=2.1.9 in ./.local/lib/python3.9/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: six in ./.local/lib/python3.9/site-packages (from pretty_midi) (1.17.0)
# Requirement already satisfied: mido>=1.1.16 in ./.local/lib/python3.9/site-packages (from pretty_midi) (1.3.3)
# Requirement already satisfied: pillow>=6.2.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: cycler>=0.10 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cffi>=1.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pytz>=2020.1 in ./.local/lib/python3.9/site-packages (from pandas) (2025.1)
# Requirement already satisfied: pycparser in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: setuptools in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from numba>=0.51.0->librosa) (65.5.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from numba>=0.51.0->librosa) (0.38.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from pooch>=1.1->librosa) (2.5.2)
# Requirement already satisfied: requests>=2.19.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from pooch>=1.1->librosa) (2.28.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /SASTRA_GPFS_CLUSTER/apps/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2022.12.7)
# WARNING: Ignoring invalid distribution -rotobuf (/nfsshare/selva/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/nfsshare/selva/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/nfsshare/selva/.local/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (/nfsshare/selva/.local/lib/python3.9/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import librosa
import pretty_midi
import numpy as np
from pathlib import Path
import tensorflow as tf

# Directory setup
base_dir = Path("/nfsshare/selva/maestro-v3.0.0/maestro-v3.0.0")
output_dir = Path("./preprocessed_output_all_480_minimal")
mel_output_dir = output_dir / "mel_spectrograms"
piano_roll_output_dir = output_dir / "piano_rolls"
output_dir.mkdir(exist_ok=True)
mel_output_dir.mkdir(exist_ok=True)
piano_roll_output_dir.mkdir(exist_ok=True)

# Parameters
sr = 16000
hop_length = 512
n_fft = 2048
n_mels = 229
n_pitches = 88
segment_length = 480  # Fixed input size for CNN

# Preprocessing functions
def preprocess_wav_to_mel(wav_path, midi_duration):
    audio, _ = librosa.load(str(wav_path), sr=sr)
    # Trim audio to MIDI duration
    max_samples = int(midi_duration * sr)
    audio = audio[:max_samples] if len(audio) > max_samples else audio
    S = librosa.feature.melspectrogram(y=audio, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
    S_db = librosa.power_to_db(S, ref=np.max)
    expected_T = (len(audio) - n_fft) // hop_length + 1
    if S_db.shape[1] > expected_T:
        S_db = S_db[:, :expected_T]
    return S_db

def preprocess_midi_to_piano_roll(midi_path, T_target, frame_rate):
    midi = pretty_midi.PrettyMIDI(str(midi_path))
    piano_roll = midi.get_piano_roll(fs=frame_rate)
    piano_roll = piano_roll[21:109, :]  # 88 pitches
    if piano_roll.shape[1] < T_target:
        padding = np.zeros((n_pitches, T_target - piano_roll.shape[1]), dtype=np.uint8)
        piano_roll = np.hstack((piano_roll, padding))
    elif piano_roll.shape[1] > T_target:
        piano_roll = piano_roll[:, :T_target]
    piano_roll = (piano_roll > 0).astype(np.uint8)
    return piano_roll

# Segment data into fixed-length chunks
def segment_data(data, segment_length, axis=1):
    T = data.shape[axis]
    if T < segment_length:
        pad_width = [(0, 0)] * len(data.shape)
        pad_width[axis] = (0, segment_length - T)
        return [np.pad(data, pad_width, mode='constant', constant_values=0)]
    segments = []
    for start in range(0, T, segment_length):
        end = min(start + segment_length, T)
        segment = data[:, start:end] if axis == 1 else data[start:end, :]
        if segment.shape[axis] < segment_length:
            pad_width = [(0, 0)] * len(segment.shape)
            pad_width[axis] = (0, segment_length - segment.shape[axis])
            segment = np.pad(segment, pad_width, mode='constant', constant_values=0)
        segments.append(segment)
    return segments

# Collect all WAV and MIDI files across subfolders
wav_files = []
for year_dir in base_dir.iterdir():
    if year_dir.is_dir():
        wav_files.extend(sorted([f for f in year_dir.glob("*.wav") if f.with_suffix(".midi").exists()]))
midi_files = [f.with_suffix(".midi") for f in wav_files]

print(f"Found {len(wav_files)} files across all subfolders in {base_dir}")

# Process all files with minimal validation
segment_counts = []  # Track number of segments per file
skipped_files = 0
for i, (wav_file, midi_file) in enumerate(zip(wav_files, midi_files)):
    print(f"Processing file {i+1}/{len(wav_files)}: {wav_file.name} (from {wav_file.parent.name})")
    
    # Get MIDI duration
    try:
        midi = pretty_midi.PrettyMIDI(str(midi_file))
        midi_duration = midi.get_end_time()
    except Exception as e:
        print(f"  Skipping {wav_file.name}: Error reading MIDI file ({e})")
        skipped_files += 1
        continue
    
    # Mel spectrogram
    try:
        S_db = preprocess_wav_to_mel(wav_file, midi_duration)
        if S_db.shape[1] < segment_length:
            print(f"  Skipping {wav_file.name}: Too short (< 480 frames)")
            skipped_files += 1
            continue
    except Exception as e:
        print(f"  Skipping {wav_file.name}: Error processing WAV file ({e})")
        skipped_files += 1
        continue
    
    # Piano-roll
    frame_rate = sr / hop_length
    piano_roll = preprocess_midi_to_piano_roll(midi_file, S_db.shape[1], frame_rate)
    
    # Segment into 480-frame chunks
    mel_segments = segment_data(S_db, segment_length, axis=1)
    piano_roll_segments = segment_data(piano_roll, segment_length, axis=1)
    
    # Minimal shape validation for the first segment
    assert mel_segments[0].shape == (n_mels, segment_length), f"Mel shape mismatch: {mel_segments[0].shape}"
    assert piano_roll_segments[0].shape == (n_pitches, segment_length), f"Piano-Roll shape mismatch: {piano_roll_segments[0].shape}"
    
    # Save segments and count
    segment_count = len(mel_segments)
    segment_counts.append(segment_count)
    for j in range(segment_count):
        mel_output_path = mel_output_dir / f"{wav_file.stem}_seg{j:04d}_mel.npy"
        piano_roll_output_path = piano_roll_output_dir / f"{midi_file.stem}_seg{j:04d}_piano_roll.npy"
        np.save(mel_output_path, mel_segments[j])
        np.save(piano_roll_output_path, piano_roll_segments[j])
    print(f"  Saved {segment_count} segments")

# Summary of processing
total_segments = sum(segment_counts)
print(f"\nProcessing Summary:")
print(f"Total files processed: {len(wav_files) - skipped_files}")
print(f"Total files skipped: {skipped_files}")
print(f"Total segments generated: {total_segments}")
print(f"Mel spectrograms saved in: {mel_output_dir}")
print(f"Piano-rolls saved in: {piano_roll_output_dir}")
# Out:
# 2025-03-14 23:41:15.582597: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-14 23:41:16.023006: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741975876.178176   32621 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741975876.185638   32621 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 23:41:16.727828: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 1276 files across all subfolders in /nfsshare/selva/maestro-v3.0.0/maestro-v3.0.0
# Processing file 1/1276: MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.wav (from 2004)
#   Saved 64 segments
# Processing file 2/1276: MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_06_Track06_wav.wav (from 2004)
#   Saved 18 segments
# Processing file 3/1276: MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_08_Track08_wav.wav (from 2004)
#   Saved 13 segments
# Processing file 4/1276: MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_10_Track10_wav.wav (from 2004)
#   Saved 21 segments
# Processing file 5/1276: MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 92 segments
# Processing file 6/1276: MIDI-Unprocessed_SMF_05_R1_2004_01_ORIG_MID--AUDIO_05_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 22 segments
# Processing file 7/1276: MIDI-Unprocessed_SMF_05_R1_2004_02-03_ORIG_MID--AUDIO_05_R1_2004_06_Track06_wav.wav (from 2004)
#   Saved 41 segments
# Processing file 8/1276: MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 32 segments
# Processing file 9/1276: MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_04_Track04_wav.wav (from 2004)
#   Saved 65 segments
# Processing file 10/1276: MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_06_Track06_wav.wav (from 2004)
#   Saved 44 segments
# Processing file 11/1276: MIDI-Unprocessed_SMF_07_R1_2004_01_ORIG_MID--AUDIO_07_R1_2004_12_Track12_wav.wav (from 2004)
#   Saved 44 segments
# Processing file 12/1276: MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_03_Track03_wav--1.wav (from 2004)
#   Saved 75 segments
# Processing file 13/1276: MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_07_Track07_wav.wav (from 2004)
#   Saved 36 segments
# Processing file 14/1276: MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_08_Track08_wav.wav (from 2004)
#   Saved 23 segments
# Processing file 15/1276: MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_09_Track09_wav.wav (from 2004)
#   Saved 17 segments
# Processing file 16/1276: MIDI-Unprocessed_SMF_12_01_2004_01-05_ORIG_MID--AUDIO_12_R1_2004_10_Track10_wav.wav (from 2004)
#   Saved 45 segments
# Processing file 17/1276: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 55 segments
# Processing file 18/1276: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_05_Track05_wav.wav (from 2004)
#   Saved 92 segments
# Processing file 19/1276: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_08_Track08_wav.wav (from 2004)
#   Saved 20 segments
# Processing file 20/1276: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_09_Track09_wav.wav (from 2004)
#   Saved 23 segments
# Processing file 21/1276: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_10_Track10_wav.wav (from 2004)
#   Saved 9 segments
# Processing file 22/1276: MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_12_Track12_wav.wav (from 2004)
#   Saved 17 segments
# Processing file 23/1276: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 16 segments
# Processing file 24/1276: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 22 segments
# Processing file 25/1276: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_04_Track04_wav.wav (from 2004)
#   Saved 15 segments
# Processing file 26/1276: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_05_Track05_wav.wav (from 2004)
#   Saved 20 segments
# Processing file 27/1276: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_06_Track06_wav.wav (from 2004)
#   Saved 16 segments
# Processing file 28/1276: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_08_Track08_wav.wav (from 2004)
#   Saved 78 segments
# Processing file 29/1276: MIDI-Unprocessed_SMF_16_R1_2004_01-08_ORIG_MID--AUDIO_16_R1_2004_13_Track13_wav.wav (from 2004)
#   Saved 64 segments
# Processing file 30/1276: MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_02_Track02_wav.wav (from 2004)
#   Saved 21 segments
# Processing file 31/1276: MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_04_Track04_wav.wav (from 2004)
#   Saved 46 segments
# Processing file 32/1276: MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORIG_MID--AUDIO_20_R2_2004_06_Track06_wav.wav (from 2004)
#   Saved 46 segments
# Processing file 33/1276: MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--1.wav (from 2004)
#   Saved 23 segments
# Processing file 34/1276: MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_02_Track02_wav--2.wav (from 2004)
#   Saved 25 segments
# Processing file 35/1276: MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 37 segments
# Processing file 36/1276: MIDI-Unprocessed_SMF_17_R1_2004_01-03_ORIG_MID--AUDIO_17_R1_2004_06_Track06_wav.wav (from 2004)
#   Saved 36 segments
# Processing file 37/1276: MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_08_Track08_wav.wav (from 2004)
#   Saved 17 segments
# Processing file 38/1276: MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--1.wav (from 2004)
#   Saved 9 segments
# Processing file 39/1276: MIDI-Unprocessed_SMF_17_R1_2004_03-06_ORIG_MID--AUDIO_20_R2_2004_12_Track12_wav--2.wav (from 2004)
#   Saved 34 segments
# Processing file 40/1276: MIDI-Unprocessed_SMF_17_R1_2004_04_ORIG_MID--AUDIO_17_R1_2004_09_Track09_wav.wav (from 2004)
#   Saved 79 segments
# Processing file 41/1276: MIDI-Unprocessed_SMF_17_R1_2004_04_ORIG_MID--AUDIO_17_R1_2004_11_Track11_wav.wav (from 2004)
#   Saved 40 segments
# Processing file 42/1276: MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 52 segments
# Processing file 43/1276: MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_05_Track05_wav.wav (from 2004)
#   Saved 9 segments
# Processing file 44/1276: MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_10_Track10_wav.wav (from 2004)
#   Saved 53 segments
# Processing file 45/1276: MIDI-Unprocessed_SMF_22_R1_2004_01-04_ORIG_MID--AUDIO_22_R1_2004_17_Track17_wav.wav (from 2004)
#   Saved 66 segments
# Processing file 46/1276: MIDI-Unprocessed_XP_01_R1_2004_01-02_ORIG_MID--AUDIO_01_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 24 segments
# Processing file 47/1276: MIDI-Unprocessed_XP_01_R1_2004_01-02_ORIG_MID--AUDIO_01_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 48 segments
# Processing file 48/1276: MIDI-Unprocessed_XP_01_R1_2004_03_ORIG_MID--AUDIO_01_R1_2004_04_Track04_wav.wav (from 2004)
#   Saved 111 segments
# Processing file 49/1276: MIDI-Unprocessed_XP_01_R1_2004_04-05_ORIG_MID--AUDIO_01_R1_2004_05_Track05_wav.wav (from 2004)
#   Saved 34 segments
# Processing file 50/1276: MIDI-Unprocessed_XP_01_R1_2004_04-05_ORIG_MID--AUDIO_01_R1_2004_06_Track06_wav.wav (from 2004)
#   Saved 43 segments
# Processing file 51/1276: MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 28 segments
# Processing file 52/1276: MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 128 segments
# Processing file 53/1276: MIDI-Unprocessed_XP_04_R1_2004_01-02_ORIG_MID--AUDIO_04_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 97 segments
# Processing file 54/1276: MIDI-Unprocessed_XP_04_R1_2004_01-02_ORIG_MID--AUDIO_04_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 42 segments
# Processing file 55/1276: MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_04_Track04_wav.wav (from 2004)
#   Saved 24 segments
# Processing file 56/1276: MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_05_Track05_wav.wav (from 2004)
#   Saved 20 segments
# Processing file 57/1276: MIDI-Unprocessed_XP_04_R1_2004_03-05_ORIG_MID--AUDIO_04_R1_2004_06_Track06_wav.wav (from 2004)
#   Saved 13 segments
# Processing file 58/1276: MIDI-Unprocessed_XP_04_R1_2004_06_ORIG_MID--AUDIO_04_R1_2004_08_Track08_wav.wav (from 2004)
#   Saved 35 segments
# Processing file 59/1276: MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_01_Track01_wav.wav (from 2004)
#   Saved 67 segments
# Processing file 60/1276: MIDI-Unprocessed_XP_04_R2_2004_01_ORIG_MID--AUDIO_04_R2_2004_02_Track02_wav.wav (from 2004)
#   Saved 85 segments
# Processing file 61/1276: MIDI-Unprocessed_XP_06_R1_2004_01_ORIG_MID--AUDIO_06_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 157 segments
# Processing file 62/1276: MIDI-Unprocessed_XP_06_R1_2004_02-03_ORIG_MID--AUDIO_06_R1_2004_05_Track05_wav.wav (from 2004)
#   Saved 49 segments
# Processing file 63/1276: MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_01_Track01_wav.wav (from 2004)
#   Saved 46 segments
# Processing file 64/1276: MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_02_Track02_wav.wav (from 2004)
#   Saved 35 segments
# Processing file 65/1276: MIDI-Unprocessed_XP_06_R2_2004_01_ORIG_MID--AUDIO_06_R2_2004_03_Track03_wav.wav (from 2004)
#   Saved 49 segments
# Processing file 66/1276: MIDI-Unprocessed_XP_08_R1_2004_01-02_ORIG_MID--AUDIO_08_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 47 segments
# Processing file 67/1276: MIDI-Unprocessed_XP_08_R1_2004_01-02_ORIG_MID--AUDIO_08_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 82 segments
# Processing file 68/1276: MIDI-Unprocessed_XP_08_R1_2004_03_ORIG_MID--AUDIO_08_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 47 segments
# Processing file 69/1276: MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_04_Track04_wav.wav (from 2004)
#   Saved 12 segments
# Processing file 70/1276: MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_05_Track05_wav--1.wav (from 2004)
#   Saved 19 segments
# Processing file 71/1276: MIDI-Unprocessed_XP_08_R1_2004_04-06_ORIG_MID--AUDIO_08_R1_2004_05_Track05_wav--2.wav (from 2004)
#   Saved 11 segments
# Processing file 72/1276: MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 14 segments
# Processing file 73/1276: MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 21 segments
# Processing file 74/1276: MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 30 segments
# Processing file 75/1276: MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_06_Track06_wav.wav (from 2004)
#   Saved 33 segments
# Processing file 76/1276: MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_07_Track07_wav.wav (from 2004)
#   Saved 11 segments
# Processing file 77/1276: MIDI-Unprocessed_XP_09_R1_2004_05_ORIG_MID--AUDIO_09_R1_2004_08_Track08_wav.wav (from 2004)
#   Saved 51 segments
# Processing file 78/1276: MIDI-Unprocessed_XP_10_R1_2004_01-02_ORIG_MID--AUDIO_10_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 14 segments
# Processing file 79/1276: MIDI-Unprocessed_XP_10_R1_2004_01-02_ORIG_MID--AUDIO_10_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 86 segments
# Processing file 80/1276: MIDI-Unprocessed_XP_10_R1_2004_03-04_ORIG_MID--AUDIO_10_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 42 segments
# Processing file 81/1276: MIDI-Unprocessed_XP_10_R1_2004_05_ORIG_MID--AUDIO_10_R1_2004_05_Track05_wav.wav (from 2004)
#   Saved 94 segments
# Processing file 82/1276: MIDI-Unprocessed_XP_11_R1_2004_01-02_ORIG_MID--AUDIO_11_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 45 segments
# Processing file 83/1276: MIDI-Unprocessed_XP_11_R1_2004_01-02_ORIG_MID--AUDIO_11_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 85 segments
# Processing file 84/1276: MIDI-Unprocessed_XP_11_R1_2004_03-04_ORIG_MID--AUDIO_11_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 21 segments
# Processing file 85/1276: MIDI-Unprocessed_XP_11_R1_2004_03-04_ORIG_MID--AUDIO_11_R1_2004_04_Track04_wav.wav (from 2004)
#   Saved 38 segments
# Processing file 86/1276: MIDI-Unprocessed_XP_14_R1_2004_01-03_ORIG_MID--AUDIO_14_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 18 segments
# Processing file 87/1276: MIDI-Unprocessed_XP_14_R1_2004_01-03_ORIG_MID--AUDIO_14_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 70 segments
# Processing file 88/1276: MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_04_Track04_wav.wav (from 2004)
#   Saved 16 segments
# Processing file 89/1276: MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_05_Track05_wav.wav (from 2004)
#   Saved 16 segments
# Processing file 90/1276: MIDI-Unprocessed_XP_14_R1_2004_04_ORIG_MID--AUDIO_14_R1_2004_06_Track06_wav.wav (from 2004)
#   Saved 8 segments
# Processing file 91/1276: MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_01_Track01_wav.wav (from 2004)
#   Saved 59 segments
# Processing file 92/1276: MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_02_Track02_wav.wav (from 2004)
#   Saved 39 segments
# Processing file 93/1276: MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_03_Track03_wav.wav (from 2004)
#   Saved 15 segments
# Processing file 94/1276: MIDI-Unprocessed_XP_14_R2_2004_01_ORIG_MID--AUDIO_14_R2_2004_04_Track04_wav.wav (from 2004)
#   Saved 30 segments
# Processing file 95/1276: MIDI-Unprocessed_XP_15_R1_2004_01-02_ORIG_MID--AUDIO_15_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 35 segments
# Processing file 96/1276: MIDI-Unprocessed_XP_15_R1_2004_01-02_ORIG_MID--AUDIO_15_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 95 segments
# Processing file 97/1276: MIDI-Unprocessed_XP_15_R1_2004_03_ORIG_MID--AUDIO_15_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 73 segments
# Processing file 98/1276: MIDI-Unprocessed_XP_15_R1_2004_04_ORIG_MID--AUDIO_15_R1_2004_04_Track04_wav.wav (from 2004)
#   Saved 77 segments
# Processing file 99/1276: MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_01_Track01_wav.wav (from 2004)
#   Saved 26 segments
# Processing file 100/1276: MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_02_Track02_wav.wav (from 2004)
#   Saved 45 segments
# Processing file 101/1276: MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_03_Track03_wav.wav (from 2004)
#   Saved 23 segments
# Processing file 102/1276: MIDI-Unprocessed_XP_15_R2_2004_01_ORIG_MID--AUDIO_15_R2_2004_04_Track04_wav.wav (from 2004)
#   Saved 29 segments
# Processing file 103/1276: MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_01_Track01_wav.wav (from 2004)
#   Saved 60 segments
# Processing file 104/1276: MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_02_Track02_wav.wav (from 2004)
#   Saved 38 segments
# Processing file 105/1276: MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_03_Track03_wav.wav (from 2004)
#   Saved 16 segments
# Processing file 106/1276: MIDI-Unprocessed_XP_16_R2_2004_01_ORIG_MID--AUDIO_16_R2_2004_04_Track04_wav.wav (from 2004)
#   Saved 32 segments
# Processing file 107/1276: MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_01_Track01_wav.wav (from 2004)
#   Saved 49 segments
# Processing file 108/1276: MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_02_Track02_wav.wav (from 2004)
#   Saved 28 segments
# Processing file 109/1276: MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_03_Track03_wav.wav (from 2004)
#   Saved 15 segments
# Processing file 110/1276: MIDI-Unprocessed_XP_17_R2_2004_01_ORIG_MID--AUDIO_17_R2_2004_04_Track04_wav.wav (from 2004)
#   Saved 34 segments
# Processing file 111/1276: MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 14 segments
# Processing file 112/1276: MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 13 segments
# Processing file 113/1276: MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_04_Track04_wav.wav (from 2004)
#   Saved 10 segments
# Processing file 114/1276: MIDI-Unprocessed_XP_18_R1_2004_01-02_ORIG_MID--AUDIO_18_R1_2004_05_Track05_wav.wav (from 2004)
#   Saved 17 segments
# Processing file 115/1276: MIDI-Unprocessed_XP_18_R1_2004_04_ORIG_MID--AUDIO_18_R1_2004_07_Track07_wav.wav (from 2004)
#   Saved 94 segments
# Processing file 116/1276: MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 14 segments
# Processing file 117/1276: MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 18 segments
# Processing file 118/1276: MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 137 segments
# Processing file 119/1276: MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_01_Track01_wav.wav (from 2004)
#   Saved 30 segments
# Processing file 120/1276: MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_02_Track02_wav.wav (from 2004)
#   Saved 31 segments
# Processing file 121/1276: MIDI-Unprocessed_XP_19_R2_2004_01_ORIG_MID--AUDIO_19_R2_2004_03_Track03_wav.wav (from 2004)
#   Saved 46 segments
# Processing file 122/1276: MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 50 segments
# Processing file 123/1276: MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 29 segments
# Processing file 124/1276: MIDI-Unprocessed_XP_20_R2_2004_01_ORIG_MID--AUDIO_20_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 45 segments
# Processing file 125/1276: MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MID--AUDIO_21_R1_2004_01_Track01_wav.wav (from 2004)
#   Saved 57 segments
# Processing file 126/1276: MIDI-Unprocessed_XP_21_R1_2004_02_ORIG_MID--AUDIO_21_R1_2004_02_Track02_wav.wav (from 2004)
#   Saved 33 segments
# Processing file 127/1276: MIDI-Unprocessed_XP_21_R1_2004_02_ORIG_MID--AUDIO_21_R1_2004_03_Track03_wav.wav (from 2004)
#   Saved 51 segments
# Processing file 128/1276: MIDI-Unprocessed_XP_21_R1_2004_03_ORIG_MID--AUDIO_21_R1_2004_04_Track04_wav.wav (from 2004)
#   Saved 129 segments
# Processing file 129/1276: MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_01_Track01_wav.wav (from 2004)
#   Saved 31 segments
# Processing file 130/1276: MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_02_Track02_wav.wav (from 2004)
#   Saved 31 segments
# Processing file 131/1276: MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_03_Track03_wav.wav (from 2004)
#   Saved 10 segments
# Processing file 132/1276: MIDI-Unprocessed_XP_22_R2_2004_01_ORIG_MID--AUDIO_22_R2_2004_04_Track04_wav.wav (from 2004)
#   Saved 36 segments
# Processing file 133/1276: MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 118 segments
# Processing file 134/1276: MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 25 segments
# Processing file 135/1276: MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 65 segments
# Processing file 136/1276: MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 32 segments
# Processing file 137/1276: MIDI-Unprocessed_01_R1_2006_01-09_ORIG_MID--AUDIO_01_R1_2006_05_Track05_wav.wav (from 2006)
#   Saved 29 segments
# Processing file 138/1276: MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_01_Track01_wav.wav (from 2006)
#   Saved 44 segments
# Processing file 139/1276: MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_02_Track02_wav.wav (from 2006)
#   Saved 29 segments
# Processing file 140/1276: MIDI-Unprocessed_01_R2_2006_01_ORIG_MID--AUDIO_01_R2_2006_03_Track03_wav.wav (from 2006)
#   Saved 59 segments
# Processing file 141/1276: MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 63 segments
# Processing file 142/1276: MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 89 segments
# Processing file 143/1276: MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 44 segments
# Processing file 144/1276: MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 62 segments
# Processing file 145/1276: MIDI-Unprocessed_03_R1_2006_01-05_ORIG_MID--AUDIO_03_R1_2006_05_Track05_wav.wav (from 2006)
#   Saved 68 segments
# Processing file 146/1276: MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 40 segments
# Processing file 147/1276: MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 78 segments
# Processing file 148/1276: MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 51 segments
# Processing file 149/1276: MIDI-Unprocessed_04_R1_2006_01-04_ORIG_MID--AUDIO_04_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 115 segments
# Processing file 150/1276: MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 31 segments
# Processing file 151/1276: MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 48 segments
# Processing file 152/1276: MIDI-Unprocessed_05_R1_2006_01-05_ORIG_MID--AUDIO_05_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 82 segments
# Processing file 153/1276: MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_01_Track01_wav.wav (from 2006)
#   Saved 51 segments
# Processing file 154/1276: MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_02_Track02_wav.wav (from 2006)
#   Saved 31 segments
# Processing file 155/1276: MIDI-Unprocessed_05_R2_2006_01_ORIG_MID--AUDIO_05_R2_2006_03_Track03_wav.wav (from 2006)
#   Saved 47 segments
# Processing file 156/1276: MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 59 segments
# Processing file 157/1276: MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 21 segments
# Processing file 158/1276: MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 114 segments
# Processing file 159/1276: MIDI-Unprocessed_06_R1_2006_01-04_ORIG_MID--AUDIO_06_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 89 segments
# Processing file 160/1276: MIDI-Unprocessed_07_R1_2006_01-04_ORIG_MID--AUDIO_07_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 55 segments
# Processing file 161/1276: MIDI-Unprocessed_07_R1_2006_01-04_ORIG_MID--AUDIO_07_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 46 segments
# Processing file 162/1276: MIDI-Unprocessed_07_R1_2006_01-04_ORIG_MID--AUDIO_07_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 94 segments
# Processing file 163/1276: MIDI-Unprocessed_07_R1_2006_01-04_ORIG_MID--AUDIO_07_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 65 segments
# Processing file 164/1276: MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_01_Track01_wav.wav (from 2006)
#   Saved 44 segments
# Processing file 165/1276: MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_02_Track02_wav.wav (from 2006)
#   Saved 28 segments
# Processing file 166/1276: MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_03_Track03_wav.wav (from 2006)
#   Saved 18 segments
# Processing file 167/1276: MIDI-Unprocessed_07_R2_2006_01_ORIG_MID--AUDIO_07_R2_2006_04_Track04_wav.wav (from 2006)
#   Saved 43 segments
# Processing file 168/1276: MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_01_Track01_wav.wav (from 2006)
#   Saved 37 segments
# Processing file 169/1276: MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_02_Track02_wav.wav (from 2006)
#   Saved 37 segments
# Processing file 170/1276: MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_03_Track03_wav.wav (from 2006)
#   Saved 103 segments
# Processing file 171/1276: MIDI-Unprocessed_08_R2_2006_01_ORIG_MID--AUDIO_08_R2_2006_01_Track01_wav.wav (from 2006)
#   Saved 45 segments
# Processing file 172/1276: MIDI-Unprocessed_08_R2_2006_01_ORIG_MID--AUDIO_08_R2_2006_02_Track02_wav.wav (from 2006)
#   Saved 28 segments
# Processing file 173/1276: MIDI-Unprocessed_08_R2_2006_01_ORIG_MID--AUDIO_08_R2_2006_03_Track03_wav.wav (from 2006)
#   Saved 55 segments
# Processing file 174/1276: MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 46 segments
# Processing file 175/1276: MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 66 segments
# Processing file 176/1276: MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 73 segments
# Processing file 177/1276: MIDI-Unprocessed_09_R1_2006_01-04_ORIG_MID--AUDIO_09_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 64 segments
# Processing file 178/1276: MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_01_Track01_wav.wav (from 2006)
#   Saved 61 segments
# Processing file 179/1276: MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_02_Track02_wav.wav (from 2006)
#   Saved 39 segments
# Processing file 180/1276: MIDI-Unprocessed_09_R2_2006_01_ORIG_MID--AUDIO_09_R2_2006_03_Track03_wav.wav (from 2006)
#   Saved 51 segments
# Processing file 181/1276: MIDI-Unprocessed_10_R1_2006_01-04_ORIG_MID--AUDIO_10_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 92 segments
# Processing file 182/1276: MIDI-Unprocessed_10_R1_2006_01-04_ORIG_MID--AUDIO_10_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 83 segments
# Processing file 183/1276: MIDI-Unprocessed_10_R1_2006_01-04_ORIG_MID--AUDIO_10_R1_2006_05_Track05_wav.wav (from 2006)
#   Saved 60 segments
# Processing file 184/1276: MIDI-Unprocessed_11_R1_2006_01-06_ORIG_MID--AUDIO_11_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 22 segments
# Processing file 185/1276: MIDI-Unprocessed_11_R1_2006_01-06_ORIG_MID--AUDIO_11_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 73 segments
# Processing file 186/1276: MIDI-Unprocessed_11_R1_2006_01-06_ORIG_MID--AUDIO_11_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 33 segments
# Processing file 187/1276: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 131 segments
# Processing file 188/1276: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 40 segments
# Processing file 189/1276: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 10 segments
# Processing file 190/1276: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 14 segments
# Processing file 191/1276: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_05_Track05_wav.wav (from 2006)
#   Saved 16 segments
# Processing file 192/1276: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_06_Track06_wav.wav (from 2006)
#   Saved 18 segments
# Processing file 193/1276: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_07_Track07_wav.wav (from 2006)
#   Saved 14 segments
# Processing file 194/1276: MIDI-Unprocessed_12_R1_2006_01-08_ORIG_MID--AUDIO_12_R1_2006_08_Track08_wav.wav (from 2006)
#   Saved 8 segments
# Processing file 195/1276: MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 27 segments
# Processing file 196/1276: MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 71 segments
# Processing file 197/1276: MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 16 segments
# Processing file 198/1276: MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_05_Track05_wav.wav (from 2006)
#   Saved 33 segments
# Processing file 199/1276: MIDI-Unprocessed_13_R1_2006_01-06_ORIG_MID--AUDIO_13_R1_2006_06_Track06_wav.wav (from 2006)
#   Saved 32 segments
# Processing file 200/1276: MIDI-Unprocessed_14_R1_2006_01-05_ORIG_MID--AUDIO_14_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 106 segments
# Processing file 201/1276: MIDI-Unprocessed_14_R1_2006_01-05_ORIG_MID--AUDIO_14_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 44 segments
# Processing file 202/1276: MIDI-Unprocessed_14_R1_2006_01-05_ORIG_MID--AUDIO_14_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 24 segments
# Processing file 203/1276: MIDI-Unprocessed_15_R1_2006_01-05_ORIG_MID--AUDIO_15_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 43 segments
# Processing file 204/1276: MIDI-Unprocessed_15_R1_2006_01-05_ORIG_MID--AUDIO_15_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 44 segments
# Processing file 205/1276: MIDI-Unprocessed_15_R1_2006_01-05_ORIG_MID--AUDIO_15_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 28 segments
# Processing file 206/1276: MIDI-Unprocessed_16_R1_2006_01-04_ORIG_MID--AUDIO_16_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 71 segments
# Processing file 207/1276: MIDI-Unprocessed_16_R1_2006_01-04_ORIG_MID--AUDIO_16_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 33 segments
# Processing file 208/1276: MIDI-Unprocessed_16_R1_2006_01-04_ORIG_MID--AUDIO_16_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 107 segments
# Processing file 209/1276: MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_01_Track01_wav.wav (from 2006)
#   Saved 56 segments
# Processing file 210/1276: MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_02_Track02_wav.wav (from 2006)
#   Saved 39 segments
# Processing file 211/1276: MIDI-Unprocessed_16_R2_2006_01_ORIG_MID--AUDIO_16_R2_2006_03_Track03_wav.wav (from 2006)
#   Saved 47 segments
# Processing file 212/1276: MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 30 segments
# Processing file 213/1276: MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 51 segments
# Processing file 214/1276: MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MID--AUDIO_17_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 27 segments
# Processing file 215/1276: MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 43 segments
# Processing file 216/1276: MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 16 segments
# Processing file 217/1276: MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 34 segments
# Processing file 218/1276: MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 50 segments
# Processing file 219/1276: MIDI-Unprocessed_18_R1_2006_01-05_ORIG_MID--AUDIO_18_R1_2006_05_Track05_wav.wav (from 2006)
#   Saved 132 segments
# Processing file 220/1276: MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 19 segments
# Processing file 221/1276: MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 34 segments
# Processing file 222/1276: MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 109 segments
# Processing file 223/1276: MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 36 segments
# Processing file 224/1276: MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_06_Track06_wav.wav (from 2006)
#   Saved 28 segments
# Processing file 225/1276: MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_07_Track07_wav.wav (from 2006)
#   Saved 24 segments
# Processing file 226/1276: MIDI-Unprocessed_20_R1_2006_01-04_ORIG_MID--AUDIO_20_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 57 segments
# Processing file 227/1276: MIDI-Unprocessed_20_R1_2006_01-04_ORIG_MID--AUDIO_20_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 105 segments
# Processing file 228/1276: MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 35 segments
# Processing file 229/1276: MIDI-Unprocessed_21_R1_2006_01-04_ORIG_MID--AUDIO_21_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 82 segments
# Processing file 230/1276: MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 68 segments
# Processing file 231/1276: MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 78 segments
# Processing file 232/1276: MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 115 segments
# Processing file 233/1276: MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_01_Track01_wav.wav (from 2006)
#   Saved 38 segments
# Processing file 234/1276: MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_02_Track02_wav.wav (from 2006)
#   Saved 52 segments
# Processing file 235/1276: MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_03_Track03_wav.wav (from 2006)
#   Saved 31 segments
# Processing file 236/1276: MIDI-Unprocessed_22_R2_2006_01_ORIG_MID--AUDIO_22_R2_2006_04_Track04_wav.wav (from 2006)
#   Saved 21 segments
# Processing file 237/1276: MIDI-Unprocessed_23_R1_2006_01-05_ORIG_MID--AUDIO_23_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 55 segments
# Processing file 238/1276: MIDI-Unprocessed_23_R1_2006_01-05_ORIG_MID--AUDIO_23_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 123 segments
# Processing file 239/1276: MIDI-Unprocessed_23_R2_2006_01_ORIG_MID--AUDIO_23_R2_2006_01_Track01_wav.wav (from 2006)
#   Saved 43 segments
# Processing file 240/1276: MIDI-Unprocessed_23_R2_2006_01_ORIG_MID--AUDIO_23_R2_2006_02_Track02_wav.wav (from 2006)
#   Saved 48 segments
# Processing file 241/1276: MIDI-Unprocessed_23_R2_2006_01_ORIG_MID--AUDIO_23_R2_2006_03_Track03_wav.wav (from 2006)
#   Saved 28 segments
# Processing file 242/1276: MIDI-Unprocessed_23_R2_2006_01_ORIG_MID--AUDIO_23_R2_2006_04_Track04_wav.wav (from 2006)
#   Saved 18 segments
# Processing file 243/1276: MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_01_Track01_wav.wav (from 2006)
#   Saved 62 segments
# Processing file 244/1276: MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_02_Track02_wav.wav (from 2006)
#   Saved 45 segments
# Processing file 245/1276: MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_03_Track03_wav.wav (from 2006)
#   Saved 28 segments
# Processing file 246/1276: MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_04_Track04_wav.wav (from 2006)
#   Saved 15 segments
# Processing file 247/1276: MIDI-Unprocessed_24_R1_2006_01-05_ORIG_MID--AUDIO_24_R1_2006_05_Track05_wav.wav (from 2006)
#   Saved 91 segments
# Processing file 248/1276: MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--1.wav (from 2008)
#   Saved 23 segments
# Processing file 249/1276: MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--2.wav (from 2008)
#   Saved 19 segments
# Processing file 250/1276: MIDI-Unprocessed_01_R1_2008_01-04_ORIG_MID--AUDIO_01_R1_2008_wav--3.wav (from 2008)
#   Saved 31 segments
# Processing file 251/1276: MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--1.wav (from 2008)
#   Saved 12 segments
# Processing file 252/1276: MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--2.wav (from 2008)
#   Saved 16 segments
# Processing file 253/1276: MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--3.wav (from 2008)
#   Saved 5 segments
# Processing file 254/1276: MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--4.wav (from 2008)
#   Saved 31 segments
# Processing file 255/1276: MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--5.wav (from 2008)
#   Saved 22 segments
# Processing file 256/1276: MIDI-Unprocessed_02_R2_2008_01-05_ORIG_MID--AUDIO_02_R2_2008_wav--1.wav (from 2008)
#   Saved 15 segments
# Processing file 257/1276: MIDI-Unprocessed_02_R2_2008_01-05_ORIG_MID--AUDIO_02_R2_2008_wav--3.wav (from 2008)
#   Saved 16 segments
# Processing file 258/1276: MIDI-Unprocessed_02_R2_2008_01-05_ORIG_MID--AUDIO_02_R2_2008_wav--4.wav (from 2008)
#   Saved 8 segments
# Processing file 259/1276: MIDI-Unprocessed_02_R2_2008_01-05_ORIG_MID--AUDIO_02_R2_2008_wav--5.wav (from 2008)
#   Saved 18 segments
# Processing file 260/1276: MIDI-Unprocessed_02_R3_2008_01-03_ORIG_MID--AUDIO_02_R3_2008_wav--1.wav (from 2008)
#   Saved 36 segments
# Processing file 261/1276: MIDI-Unprocessed_02_R3_2008_01-03_ORIG_MID--AUDIO_02_R3_2008_wav--2.wav (from 2008)
#   Saved 23 segments
# Processing file 262/1276: MIDI-Unprocessed_02_R3_2008_01-03_ORIG_MID--AUDIO_02_R3_2008_wav--3.wav (from 2008)
#   Saved 62 segments
# Processing file 263/1276: MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--1.wav (from 2008)
#   Saved 24 segments
# Processing file 264/1276: MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--2.wav (from 2008)
#   Saved 39 segments
# Processing file 265/1276: MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--3.wav (from 2008)
#   Saved 9 segments
# Processing file 266/1276: MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--4.wav (from 2008)
#   Saved 28 segments
# Processing file 267/1276: MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MID--AUDIO_03_R2_2008_wav--1.wav (from 2008)
#   Saved 35 segments
# Processing file 268/1276: MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MID--AUDIO_03_R2_2008_wav--2.wav (from 2008)
#   Saved 50 segments
# Processing file 269/1276: MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MID--AUDIO_03_R2_2008_wav--3.wav (from 2008)
#   Saved 42 segments
# Processing file 270/1276: MIDI-Unprocessed_03_R3_2008_01-03_ORIG_MID--AUDIO_03_R3_2008_wav--1.wav (from 2008)
#   Saved 42 segments
# Processing file 271/1276: MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MID--AUDIO_04_R1_2008_wav--1.wav (from 2008)
#   Saved 23 segments
# Processing file 272/1276: MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MID--AUDIO_04_R1_2008_wav--2.wav (from 2008)
#   Saved 22 segments
# Processing file 273/1276: MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MID--AUDIO_04_R1_2008_wav--4.wav (from 2008)
#   Saved 42 segments
# Processing file 274/1276: MIDI-Unprocessed_04_R2_2008_01-04_ORIG_MID--AUDIO_04_R2_2008_wav--1.wav (from 2008)
#   Saved 21 segments
# Processing file 275/1276: MIDI-Unprocessed_04_R2_2008_01-04_ORIG_MID--AUDIO_04_R2_2008_wav--3.wav (from 2008)
#   Saved 27 segments
# Processing file 276/1276: MIDI-Unprocessed_04_R2_2008_01-04_ORIG_MID--AUDIO_04_R2_2008_wav--4.wav (from 2008)
#   Saved 52 segments
# Processing file 277/1276: MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--1.wav (from 2008)
#   Saved 42 segments
# Processing file 278/1276: MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--2.wav (from 2008)
#   Saved 4 segments
# Processing file 279/1276: MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--3.wav (from 2008)
#   Saved 17 segments
# Processing file 280/1276: MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--4.wav (from 2008)
#   Saved 33 segments
# Processing file 281/1276: MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--5.wav (from 2008)
#   Saved 16 segments
# Processing file 282/1276: MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--6.wav (from 2008)
#   Saved 20 segments
# Processing file 283/1276: MIDI-Unprocessed_04_R3_2008_01-07_ORIG_MID--AUDIO_04_R3_2008_wav--7.wav (from 2008)
#   Saved 40 segments
# Processing file 284/1276: MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--1.wav (from 2008)
#   Saved 29 segments
# Processing file 285/1276: MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--2.wav (from 2008)
#   Saved 19 segments
# Processing file 286/1276: MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--3.wav (from 2008)
#   Saved 23 segments
# Processing file 287/1276: MIDI-Unprocessed_05_R1_2008_01-04_ORIG_MID--AUDIO_05_R1_2008_wav--4.wav (from 2008)
#   Saved 18 segments
# Processing file 288/1276: MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--1.wav (from 2008)
#   Saved 15 segments
# Processing file 289/1276: MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--2.wav (from 2008)
#   Saved 27 segments
# Processing file 290/1276: MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--3.wav (from 2008)
#   Saved 15 segments
# Processing file 291/1276: MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--4.wav (from 2008)
#   Saved 20 segments
# Processing file 292/1276: MIDI-Unprocessed_06_R2_2008_01-05_ORIG_MID--AUDIO_06_R2_2008_wav--1.wav (from 2008)
#   Saved 12 segments
# Processing file 293/1276: MIDI-Unprocessed_06_R2_2008_01-05_ORIG_MID--AUDIO_06_R2_2008_wav--3.wav (from 2008)
#   Saved 39 segments
# Processing file 294/1276: MIDI-Unprocessed_06_R2_2008_01-05_ORIG_MID--AUDIO_06_R2_2008_wav--4.wav (from 2008)
#   Saved 19 segments
# Processing file 295/1276: MIDI-Unprocessed_06_R2_2008_01-05_ORIG_MID--AUDIO_06_R2_2008_wav--5.wav (from 2008)
#   Saved 15 segments
# Processing file 296/1276: MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--1.wav (from 2008)
#   Saved 15 segments
# Processing file 297/1276: MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--2.wav (from 2008)
#   Saved 21 segments
# Processing file 298/1276: MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--3.wav (from 2008)
#   Saved 17 segments
# Processing file 299/1276: MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--4.wav (from 2008)
#   Saved 40 segments
# Processing file 300/1276: MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--1.wav (from 2008)
#   Saved 25 segments
# Processing file 301/1276: MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--2.wav (from 2008)
#   Saved 7 segments
# Processing file 302/1276: MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--3.wav (from 2008)
#   Saved 9 segments
# Processing file 303/1276: MIDI-Unprocessed_07_R2_2008_01-05_ORIG_MID--AUDIO_07_R2_2008_wav--4.wav (from 2008)
#   Saved 28 segments
# Processing file 304/1276: MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--1.wav (from 2008)
#   Saved 16 segments
# Processing file 305/1276: MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--2.wav (from 2008)
#   Saved 45 segments
# Processing file 306/1276: MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--3.wav (from 2008)
#   Saved 12 segments
# Processing file 307/1276: MIDI-Unprocessed_07_R3_2008_01-05_ORIG_MID--AUDIO_07_R3_2008_wav--4.wav (from 2008)
#   Saved 14 segments
# Processing file 308/1276: MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--1.wav (from 2008)
#   Saved 11 segments
# Processing file 309/1276: MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--2.wav (from 2008)
#   Saved 20 segments
# Processing file 310/1276: MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--3.wav (from 2008)
#   Saved 11 segments
# Processing file 311/1276: MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--4.wav (from 2008)
#   Saved 43 segments
# Processing file 312/1276: MIDI-Unprocessed_08_R1_2008_01-05_ORIG_MID--AUDIO_08_R1_2008_wav--5.wav (from 2008)
#   Saved 5 segments
# Processing file 313/1276: MIDI-Unprocessed_08_R2_2008_01-04_ORIG_MID--AUDIO_08_R2_2008_wav--1.wav (from 2008)
#   Saved 41 segments
# Processing file 314/1276: MIDI-Unprocessed_08_R2_2008_01-04_ORIG_MID--AUDIO_08_R2_2008_wav--2.wav (from 2008)
#   Saved 24 segments
# Processing file 315/1276: MIDI-Unprocessed_08_R2_2008_01-04_ORIG_MID--AUDIO_08_R2_2008_wav--4.wav (from 2008)
#   Saved 18 segments
# Processing file 316/1276: MIDI-Unprocessed_08_R3_2008_01-05_ORIG_MID--AUDIO_08_R3_2008_wav--1.wav (from 2008)
#   Saved 31 segments
# Processing file 317/1276: MIDI-Unprocessed_08_R3_2008_01-05_ORIG_MID--AUDIO_08_R3_2008_wav--2.wav (from 2008)
#   Saved 49 segments
# Processing file 318/1276: MIDI-Unprocessed_08_R3_2008_01-05_ORIG_MID--AUDIO_08_R3_2008_wav--3.wav (from 2008)
#   Saved 42 segments
# Processing file 319/1276: MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--1.wav (from 2008)
#   Saved 15 segments
# Processing file 320/1276: MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--2.wav (from 2008)
#   Saved 23 segments
# Processing file 321/1276: MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--3.wav (from 2008)
#   Saved 18 segments
# Processing file 322/1276: MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--4.wav (from 2008)
#   Saved 11 segments
# Processing file 323/1276: MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--5.wav (from 2008)
#   Saved 24 segments
# Processing file 324/1276: MIDI-Unprocessed_09_R2_2008_01-05_ORIG_MID--AUDIO_09_R2_2008_wav--1.wav (from 2008)
#   Saved 18 segments
# Processing file 325/1276: MIDI-Unprocessed_09_R2_2008_01-05_ORIG_MID--AUDIO_09_R2_2008_wav--2.wav (from 2008)
#   Saved 13 segments
# Processing file 326/1276: MIDI-Unprocessed_09_R2_2008_01-05_ORIG_MID--AUDIO_09_R2_2008_wav--3.wav (from 2008)
#   Saved 28 segments
# Processing file 327/1276: MIDI-Unprocessed_09_R2_2008_01-05_ORIG_MID--AUDIO_09_R2_2008_wav--5.wav (from 2008)
#   Saved 35 segments
# Processing file 328/1276: MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--1.wav (from 2008)
#   Saved 14 segments
# Processing file 329/1276: MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--2.wav (from 2008)
#   Saved 5 segments
# Processing file 330/1276: MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--3.wav (from 2008)
#   Saved 8 segments
# Processing file 331/1276: MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--4.wav (from 2008)
#   Saved 43 segments
# Processing file 332/1276: MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--5.wav (from 2008)
#   Saved 41 segments
# Processing file 333/1276: MIDI-Unprocessed_09_R3_2008_01-07_ORIG_MID--AUDIO_09_R3_2008_wav--7.wav (from 2008)
#   Saved 21 segments
# Processing file 334/1276: MIDI-Unprocessed_10_R1_2008_01-04_ORIG_MID--AUDIO_10_R1_2008_wav--1.wav (from 2008)
#   Saved 13 segments
# Processing file 335/1276: MIDI-Unprocessed_10_R1_2008_01-04_ORIG_MID--AUDIO_10_R1_2008_wav--2.wav (from 2008)
#   Saved 29 segments
# Processing file 336/1276: MIDI-Unprocessed_10_R1_2008_01-04_ORIG_MID--AUDIO_10_R1_2008_wav--3.wav (from 2008)
#   Saved 36 segments
# Processing file 337/1276: MIDI-Unprocessed_10_R1_2008_01-04_ORIG_MID--AUDIO_10_R1_2008_wav--4.wav (from 2008)
#   Saved 18 segments
# Processing file 338/1276: MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--1.wav (from 2008)
#   Saved 7 segments
# Processing file 339/1276: MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--2.wav (from 2008)
#   Saved 10 segments
# Processing file 340/1276: MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--3.wav (from 2008)
#   Saved 35 segments
# Processing file 341/1276: MIDI-Unprocessed_10_R2_2008_01-05_ORIG_MID--AUDIO_10_R2_2008_wav--4.wav (from 2008)
#   Saved 23 segments
# Processing file 342/1276: MIDI-Unprocessed_10_R3_2008_01-05_ORIG_MID--AUDIO_10_R3_2008_wav--1.wav (from 2008)
#   Saved 43 segments
# ...
#   Saved 25 segments
# Processing file 1152/1276: MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--3.wav (from 2017)
#   Saved 27 segments
# Processing file 1153/1276: MIDI-Unprocessed_072_PIANO072_MID--AUDIO-split_07-08-17_Piano-e_1-06_wav--4.wav (from 2017)
#   Saved 36 segments
# Processing file 1154/1276: MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--1.wav (from 2017)
#   Saved 44 segments
# Processing file 1155/1276: MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--2.wav (from 2017)
#   Saved 25 segments
# Processing file 1156/1276: MIDI-Unprocessed_073_PIANO073_MID--AUDIO-split_07-08-17_Piano-e_2-02_wav--4.wav (from 2017)
#   Saved 64 segments
# Processing file 1157/1276: MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--1.wav (from 2017)
#   Saved 47 segments
# Processing file 1158/1276: MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--2.wav (from 2017)
#   Saved 45 segments
# Processing file 1159/1276: MIDI-Unprocessed_074_PIANO074_MID--AUDIO-split_07-08-17_Piano-e_2-04_wav--3.wav (from 2017)
#   Saved 64 segments
# Processing file 1160/1276: MIDI-Unprocessed_075_PIANO075_MID--AUDIO-split_07-08-17_Piano-e_2-06_wav--1.wav (from 2017)
#   Saved 38 segments
# Processing file 1161/1276: MIDI-Unprocessed_075_PIANO075_MID--AUDIO-split_07-08-17_Piano-e_2-06_wav--2.wav (from 2017)
#   Saved 40 segments
# Processing file 1162/1276: MIDI-Unprocessed_075_PIANO075_MID--AUDIO-split_07-08-17_Piano-e_2-06_wav--3.wav (from 2017)
#   Saved 26 segments
# Processing file 1163/1276: MIDI-Unprocessed_078_PIANO078_MID--AUDIO-split_07-09-17_Piano-e_1-02_wav--1.wav (from 2017)
#   Saved 40 segments
# Processing file 1164/1276: MIDI-Unprocessed_078_PIANO078_MID--AUDIO-split_07-09-17_Piano-e_1-02_wav--2.wav (from 2017)
#   Saved 59 segments
# Processing file 1165/1276: MIDI-Unprocessed_078_PIANO078_MID--AUDIO-split_07-09-17_Piano-e_1-02_wav--3.wav (from 2017)
#   Saved 44 segments
# Processing file 1166/1276: MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--1.wav (from 2017)
#   Saved 30 segments
# Processing file 1167/1276: MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--2.wav (from 2017)
#   Saved 37 segments
# Processing file 1168/1276: MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--3.wav (from 2017)
#   Saved 45 segments
# Processing file 1169/1276: MIDI-Unprocessed_079_PIANO079_MID--AUDIO-split_07-09-17_Piano-e_1-04_wav--4.wav (from 2017)
#   Saved 44 segments
# Processing file 1170/1276: MIDI-Unprocessed_080_PIANO080_MID--AUDIO-split_07-09-17_Piano-e_1-06_wav--1.wav (from 2017)
#   Saved 37 segments
# Processing file 1171/1276: MIDI-Unprocessed_080_PIANO080_MID--AUDIO-split_07-09-17_Piano-e_1-06_wav--2.wav (from 2017)
#   Saved 42 segments
# Processing file 1172/1276: MIDI-Unprocessed_080_PIANO080_MID--AUDIO-split_07-09-17_Piano-e_1-06_wav--3.wav (from 2017)
#   Saved 79 segments
# Processing file 1173/1276: MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--1.wav (from 2017)
#   Saved 41 segments
# Processing file 1174/1276: MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--3.wav (from 2017)
#   Saved 37 segments
# Processing file 1175/1276: MIDI-Unprocessed_081_PIANO081_MID--AUDIO-split_07-09-17_Piano-e_2_-02_wav--4.wav (from 2017)
#   Saved 26 segments
# Processing file 1176/1276: MIDI-Unprocessed_082_PIANO082_MID--AUDIO-split_07-09-17_Piano-e_2_-04_wav--1.wav (from 2017)
#   Saved 39 segments
# Processing file 1177/1276: MIDI-Unprocessed_082_PIANO082_MID--AUDIO-split_07-09-17_Piano-e_2_-04_wav--2.wav (from 2017)
#   Saved 54 segments
# Processing file 1178/1276: MIDI-Unprocessed_082_PIANO082_MID--AUDIO-split_07-09-17_Piano-e_2_-04_wav--3.wav (from 2017)
#   Saved 22 segments
# Processing file 1179/1276: MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--1.wav (from 2017)
#   Saved 16 segments
# Processing file 1180/1276: MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--2.wav (from 2017)
#   Saved 7 segments
# Processing file 1181/1276: MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--3.wav (from 2017)
#   Saved 21 segments
# Processing file 1182/1276: MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--4.wav (from 2017)
#   Saved 42 segments
# Processing file 1183/1276: MIDI-Unprocessed_083_PIANO083_MID--AUDIO-split_07-09-17_Piano-e_2_-06_wav--5.wav (from 2017)
#   Saved 18 segments
# Processing file 1184/1276: MIDI-Unprocessed_Chamber2_MID--AUDIO_09_R3_2018_wav--1.wav (from 2018)
#   Saved 38 segments
# Processing file 1185/1276: MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--1.wav (from 2018)
#   Saved 46 segments
# Processing file 1186/1276: MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R3_2018_wav--2.wav (from 2018)
#   Saved 55 segments
# Processing file 1187/1276: MIDI-Unprocessed_Chamber4_MID--AUDIO_11_R3_2018_wav--1.wav (from 2018)
#   Saved 72 segments
# Processing file 1188/1276: MIDI-Unprocessed_Chamber5_MID--AUDIO_18_R3_2018_wav--1.wav (from 2018)
#   Saved 105 segments
# Processing file 1189/1276: MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--1.wav (from 2018)
#   Saved 35 segments
# Processing file 1190/1276: MIDI-Unprocessed_Chamber6_MID--AUDIO_20_R3_2018_wav--2.wav (from 2018)
#   Saved 73 segments
# Processing file 1191/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--1.wav (from 2018)
#   Saved 22 segments
# Processing file 1192/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--2.wav (from 2018)
#   Saved 42 segments
# Processing file 1193/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--3.wav (from 2018)
#   Saved 105 segments
# Processing file 1194/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_01_R1_2018_wav--4.wav (from 2018)
#   Saved 46 segments
# Processing file 1195/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--1.wav (from 2018)
#   Saved 161 segments
# Processing file 1196/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--2.wav (from 2018)
#   Saved 52 segments
# Processing file 1197/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--3.wav (from 2018)
#   Saved 29 segments
# Processing file 1198/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_02_R1_2018_wav--4.wav (from 2018)
#   Saved 23 segments
# Processing file 1199/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--1.wav (from 2018)
#   Saved 82 segments
# Processing file 1200/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--2.wav (from 2018)
#   Saved 133 segments
# Processing file 1201/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--4.wav (from 2018)
#   Saved 17 segments
# Processing file 1202/1276: MIDI-Unprocessed_Recital1-3_MID--AUDIO_03_R1_2018_wav--5.wav (from 2018)
#   Saved 11 segments
# Processing file 1203/1276: MIDI-Unprocessed_Recital12_MID--AUDIO_12_R1_2018_wav--1.wav (from 2018)
#   Saved 53 segments
# Processing file 1204/1276: MIDI-Unprocessed_Recital12_MID--AUDIO_12_R1_2018_wav--2.wav (from 2018)
#   Saved 46 segments
# Processing file 1205/1276: MIDI-Unprocessed_Recital12_MID--AUDIO_12_R1_2018_wav--3.wav (from 2018)
#   Saved 42 segments
# Processing file 1206/1276: MIDI-Unprocessed_Recital13-15_MID--AUDIO_13_R1_2018_wav--1.wav (from 2018)
#   Saved 70 segments
# Processing file 1207/1276: MIDI-Unprocessed_Recital13-15_MID--AUDIO_13_R1_2018_wav--2.wav (from 2018)
#   Saved 100 segments
# Processing file 1208/1276: MIDI-Unprocessed_Recital13-15_MID--AUDIO_13_R1_2018_wav--3.wav (from 2018)
#   Saved 107 segments
# Processing file 1209/1276: MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--1.wav (from 2018)
#   Saved 48 segments
# Processing file 1210/1276: MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--2.wav (from 2018)
#   Saved 77 segments
# Processing file 1211/1276: MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--3.wav (from 2018)
#   Saved 24 segments
# Processing file 1212/1276: MIDI-Unprocessed_Recital13-15_MID--AUDIO_14_R1_2018_wav--4.wav (from 2018)
#   Saved 55 segments
# Processing file 1213/1276: MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--1.wav (from 2018)
#   Saved 34 segments
# Processing file 1214/1276: MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--2.wav (from 2018)
#   Saved 17 segments
# Processing file 1215/1276: MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--3.wav (from 2018)
#   Saved 104 segments
# Processing file 1216/1276: MIDI-Unprocessed_Recital13-15_MID--AUDIO_15_R1_2018_wav--4.wav (from 2018)
#   Saved 100 segments
# Processing file 1217/1276: MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--2.wav (from 2018)
#   Saved 48 segments
# Processing file 1218/1276: MIDI-Unprocessed_Recital16_MID--AUDIO_16_R1_2018_wav--3.wav (from 2018)
#   Saved 17 segments
# Processing file 1219/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--1.wav (from 2018)
#   Saved 21 segments
# Processing file 1220/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--2.wav (from 2018)
#   Saved 20 segments
# Processing file 1221/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--3.wav (from 2018)
#   Saved 70 segments
# Processing file 1222/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_17_R1_2018_wav--4.wav (from 2018)
#   Saved 124 segments
# Processing file 1223/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--1.wav (from 2018)
#   Saved 86 segments
# Processing file 1224/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--2.wav (from 2018)
#   Saved 45 segments
# Processing file 1225/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_18_R1_2018_wav--3.wav (from 2018)
#   Saved 10 segments
# Processing file 1226/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--1.wav (from 2018)
#   Saved 42 segments
# Processing file 1227/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--2.wav (from 2018)
#   Saved 67 segments
# Processing file 1228/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--3.wav (from 2018)
#   Saved 16 segments
# Processing file 1229/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--4.wav (from 2018)
#   Saved 65 segments
# Processing file 1230/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--5.wav (from 2018)
#   Saved 16 segments
# Processing file 1231/1276: MIDI-Unprocessed_Recital17-19_MID--AUDIO_19_R1_2018_wav--6.wav (from 2018)
#   Saved 46 segments
# Processing file 1232/1276: MIDI-Unprocessed_Recital20_MID--AUDIO_20_R1_2018_wav--3.wav (from 2018)
#   Saved 56 segments
# Processing file 1233/1276: MIDI-Unprocessed_Recital20_MID--AUDIO_20_R1_2018_wav--4.wav (from 2018)
#   Saved 137 segments
# Processing file 1234/1276: MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--1.wav (from 2018)
#   Saved 30 segments
# Processing file 1235/1276: MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--3.wav (from 2018)
#   Saved 50 segments
# Processing file 1236/1276: MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--4.wav (from 2018)
#   Saved 64 segments
# Processing file 1237/1276: MIDI-Unprocessed_Recital4_MID--AUDIO_04_R1_2018_wav--5.wav (from 2018)
#   Saved 111 segments
# Processing file 1238/1276: MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--1.wav (from 2018)
#   Saved 73 segments
# Processing file 1239/1276: MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--2.wav (from 2018)
#   Saved 102 segments
# Processing file 1240/1276: MIDI-Unprocessed_Recital5-7_MID--AUDIO_05_R1_2018_wav--3.wav (from 2018)
#   Saved 89 segments
# Processing file 1241/1276: MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--1.wav (from 2018)
#   Saved 87 segments
# Processing file 1242/1276: MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--2.wav (from 2018)
#   Saved 95 segments
# Processing file 1243/1276: MIDI-Unprocessed_Recital5-7_MID--AUDIO_06_R1_2018_wav--3.wav (from 2018)
#   Saved 96 segments
# Processing file 1244/1276: MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--1.wav (from 2018)
#   Saved 62 segments
# Processing file 1245/1276: MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--2.wav (from 2018)
#   Saved 73 segments
# Processing file 1246/1276: MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--3.wav (from 2018)
#   Saved 20 segments
# Processing file 1247/1276: MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--4.wav (from 2018)
#   Saved 119 segments
# Processing file 1248/1276: MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--1.wav (from 2018)
#   Saved 53 segments
# Processing file 1249/1276: MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--2.wav (from 2018)
#   Saved 69 segments
# Processing file 1250/1276: MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--3.wav (from 2018)
#   Saved 41 segments
# Processing file 1251/1276: MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--4.wav (from 2018)
#   Saved 125 segments
# Processing file 1252/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--1.wav (from 2018)
#   Saved 90 segments
# Processing file 1253/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--2.wav (from 2018)
#   Saved 14 segments
# Processing file 1254/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--3.wav (from 2018)
#   Saved 20 segments
# Processing file 1255/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--4.wav (from 2018)
#   Saved 18 segments
# Processing file 1256/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--5.wav (from 2018)
#   Saved 15 segments
# Processing file 1257/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_09_R1_2018_wav--6.wav (from 2018)
#   Saved 13 segments
# Processing file 1258/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--1.wav (from 2018)
#   Saved 56 segments
# Processing file 1259/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--2.wav (from 2018)
#   Saved 70 segments
# Processing file 1260/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--3.wav (from 2018)
#   Saved 20 segments
# Processing file 1261/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_10_R1_2018_wav--5.wav (from 2018)
#   Saved 67 segments
# Processing file 1262/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--1.wav (from 2018)
#   Saved 38 segments
# Processing file 1263/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--2.wav (from 2018)
#   Saved 78 segments
# Processing file 1264/1276: MIDI-Unprocessed_Recital9-11_MID--AUDIO_11_R1_2018_wav--5.wav (from 2018)
#   Saved 123 segments
# Processing file 1265/1276: MIDI-Unprocessed_Schubert1-3_MID--AUDIO_02_R2_2018_wav.wav (from 2018)
#   Saved 121 segments
# Processing file 1266/1276: MIDI-Unprocessed_Schubert1-3_MID--AUDIO_05_R2_2018_wav.wav (from 2018)
#   Saved 114 segments
# Processing file 1267/1276: MIDI-Unprocessed_Schubert1-3_MID--AUDIO_07_R2_2018_wav.wav (from 2018)
#   Saved 147 segments
# Processing file 1268/1276: MIDI-Unprocessed_Schubert10-12_MID--AUDIO_17_R2_2018_wav.wav (from 2018)
#   Saved 124 segments
# Processing file 1269/1276: MIDI-Unprocessed_Schubert10-12_MID--AUDIO_18_R2_2018_wav.wav (from 2018)
#   Saved 130 segments
# Processing file 1270/1276: MIDI-Unprocessed_Schubert10-12_MID--AUDIO_20_R2_2018_wav.wav (from 2018)
#   Saved 153 segments
# Processing file 1271/1276: MIDI-Unprocessed_Schubert4-6_MID--AUDIO_08_R2_2018_wav.wav (from 2018)
#   Saved 114 segments
# Processing file 1272/1276: MIDI-Unprocessed_Schubert4-6_MID--AUDIO_09_R2_2018_wav.wav (from 2018)
#   Saved 167 segments
# Processing file 1273/1276: MIDI-Unprocessed_Schubert4-6_MID--AUDIO_10_R2_2018_wav.wav (from 2018)
#   Saved 158 segments
# Processing file 1274/1276: MIDI-Unprocessed_Schubert7-9_MID--AUDIO_11_R2_2018_wav.wav (from 2018)
#   Saved 107 segments
# Processing file 1275/1276: MIDI-Unprocessed_Schubert7-9_MID--AUDIO_15_R2_2018_wav.wav (from 2018)
#   Saved 136 segments
# Processing file 1276/1276: MIDI-Unprocessed_Schubert7-9_MID--AUDIO_16_R2_2018_wav.wav (from 2018)
#   Saved 115 segments
#
# Processing Summary:
# Total files processed: 1276
# Total files skipped: 0
# Total segments generated: 47268
# Mel spectrograms saved in: preprocessed_output_all_480_minimal/mel_spectrograms
# Piano-rolls saved in: preprocessed_output_all_480_minimal/piano_rolls

# %%
import os
import shutil
import numpy as np
from pathlib import Path
from collections import defaultdict

# Input directories (from previous preprocessing)
base_output_dir = Path("./preprocessed_output_all_480_minimal")
mel_input_dir = base_output_dir / "mel_spectrograms"
piano_roll_input_dir = base_output_dir / "piano_rolls"

# Output directories for train, val, test splits
mel_train_dir = mel_input_dir / "train"
mel_val_dir = mel_input_dir / "val"
mel_test_dir = mel_input_dir / "test"
piano_roll_train_dir = piano_roll_input_dir / "train"
piano_roll_val_dir = piano_roll_input_dir / "val"
piano_roll_test_dir = piano_roll_input_dir / "test"

# Create directories
for d in [mel_train_dir, mel_val_dir, mel_test_dir, piano_roll_train_dir, piano_roll_val_dir, piano_roll_test_dir]:
    d.mkdir(exist_ok=True)

# Step 1: Collect all Mel spectrogram files and group by original file
mel_files = sorted(list(mel_input_dir.glob("*_mel.npy")))
print(f"Total Mel spectrogram segments: {len(mel_files)}")

# Group segments by original file (based on filename before "_segXXXX_mel.npy")
file_groups = defaultdict(list)
for mel_file in mel_files:
    # Extract the base filename (e.g., "MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav")
    base_name = mel_file.stem.split("_seg")[0]
    file_groups[base_name].append(mel_file)

# Step 2: Split files into train, val, test (80-10-10)
file_names = list(file_groups.keys())
np.random.seed(42)  # For reproducibility
np.random.shuffle(file_names)

total_files = len(file_names)
train_split = int(0.8 * total_files)  # 80%
val_split = int(0.1 * total_files)    # 10%
test_split = total_files - train_split - val_split  # Remaining 10%

train_files = file_names[:train_split]
val_files = file_names[train_split:train_split + val_split]
test_files = file_names[train_split + val_split:]

print(f"Total files: {total_files}")
print(f"Train files: {len(train_files)} ({len(train_files)/total_files*100:.1f}%)")
print(f"Val files: {len(val_files)} ({len(val_files)/total_files*100:.1f}%)")
print(f"Test files: {len(test_files)} ({len(test_files)/total_files*100:.1f}%)")

# Step 3: Move Mel spectrograms and piano-rolls to appropriate directories
def move_files(file_list, split_name, mel_dest_dir, piano_roll_dest_dir):
    mel_count = 0
    piano_roll_count = 0
    for base_name in file_list:
        # Move Mel spectrograms
        mel_segments = file_groups[base_name]
        for mel_file in mel_segments:
            dest_path = mel_dest_dir / mel_file.name
            shutil.move(str(mel_file), str(dest_path))
            mel_count += 1
        
        # Move corresponding piano-rolls
        piano_roll_segments = [piano_roll_input_dir / mel_file.name.replace("_mel.npy", "_piano_roll.npy") for mel_file in mel_segments]
        for piano_roll_file in piano_roll_segments:
            if piano_roll_file.exists():
                dest_path = piano_roll_dest_dir / piano_roll_file.name
                shutil.move(str(piano_roll_file), str(dest_path))
                piano_roll_count += 1
            else:
                print(f"Warning: Piano-roll file {piano_roll_file} not found for {base_name}")
    
    print(f"\nMoved to {split_name}:")
    print(f"  Mel spectrograms: {mel_count} segments")
    print(f"  Piano-rolls: {piano_roll_count} segments")

# Move files to train, val, test directories
move_files(train_files, "train", mel_train_dir, piano_roll_train_dir)
move_files(val_files, "val", mel_val_dir, piano_roll_val_dir)
move_files(test_files, "test", mel_test_dir, piano_roll_test_dir)

print("\nDataset split completed.")
print(f"Train: {mel_train_dir}, {piano_roll_train_dir}")
print(f"Val: {mel_val_dir}, {piano_roll_val_dir}")
print(f"Test: {mel_test_dir}, {piano_roll_test_dir}")
# Out:
# Total Mel spectrogram segments: 47268
# Total files: 1276
# Train files: 1020 (79.9%)
# Val files: 127 (10.0%)
# Test files: 129 (10.1%)
#
# Moved to train:
#   Mel spectrograms: 37993 segments
#   Piano-rolls: 37993 segments
#
# Moved to val:
#   Mel spectrograms: 4113 segments
#   Piano-rolls: 4113 segments
#
# Moved to test:
#   Mel spectrograms: 5162 segments
#   Piano-rolls: 5162 segments
#
# Dataset split completed.
# Train: preprocessed_output_all_480_minimal/mel_spectrograms/train, preprocessed_output_all_480_minimal/piano_rolls/train
# Val: preprocessed_output_all_480_minimal/mel_spectrograms/val, preprocessed_output_all_480_minimal/piano_rolls/val
# Test: preprocessed_output_all_480_minimal/mel_spectrograms/test, preprocessed_output_all_480_minimal/piano_rolls/test

# %%
import numpy as np
from pathlib import Path
from scipy.stats import pearsonr
import tensorflow as tf

# Directory for training piano-rolls
piano_roll_train_dir = Path("./preprocessed_output_all_480_minimal/piano_rolls/train")

# Parameters
n_pitches = 88
max_files_to_process = 37993
target_sparsity = (0.94, 0.96)  # Adjusted to hit ~0.95
threshold_range = np.linspace(0.15, 0.25, 21)  # Narrow range to target ~200 edges

# Step 1: Load training piano-rolls and compute note activations
piano_roll_files = sorted(list(piano_roll_train_dir.glob("*_piano_roll.npy")))
print(f"Found {len(piano_roll_files)} training piano-roll segments")
print(f"Processing up to {max_files_to_process} segments for efficiency")

total_frames = 0
processed_files = 0
for i, piano_roll_file in enumerate(piano_roll_files):
    if processed_files >= max_files_to_process:
        break
    piano_roll = np.load(piano_roll_file)
    total_frames += piano_roll.shape[1]
    processed_files += 1

note_activations = np.zeros((n_pitches, total_frames), dtype=np.uint8)
current_frame = 0
processed_files = 0
for i, piano_roll_file in enumerate(piano_roll_files):
    if processed_files >= max_files_to_process:
        break
    if i % 1000 == 0:
        print(f"Processing piano-roll {i}/{len(piano_roll_files)}")
    
    piano_roll = np.load(piano_roll_file)
    piano_roll = (piano_roll > 0).astype(np.uint8)
    num_frames = piano_roll.shape[1]
    note_activations[:, current_frame:current_frame + num_frames] = piano_roll
    current_frame += num_frames
    processed_files += 1

# Step 2: Compute Pearson Correlation Matrix
P_pearson = np.zeros((n_pitches, n_pitches), dtype=np.float32)
for i in range(n_pitches):
    for j in range(i + 1, n_pitches):
        if np.sum(note_activations[i, :]) == 0 or np.sum(note_activations[j, :]) == 0:
            corr = 0.0
        else:
            corr, _ = pearsonr(note_activations[i, :], note_activations[j, :])
        P_pearson[i, j] = corr
        P_pearson[j, i] = corr

print("\nPearson Correlation Matrix Statistics:")
print(f"Min value: {P_pearson.min():.4f}")
print(f"Max value: {P_pearson.max():.4f}")
print(f"Mean value: {P_pearson.mean():.4f}")

# Step 3: Find optimal threshold based on sparsity
def get_adjacency_matrix(P, tau):
    A = (P >= tau).astype(np.int32)
    np.fill_diagonal(A, 0)
    A_symmetric = np.logical_or(A, A.T).astype(np.int32)
    np.fill_diagonal(A_symmetric, 0)
    n_edges = np.sum(A_symmetric) // 2
    sparsity = np.sum(A_symmetric == 0) / (n_pitches * n_pitches)
    return A_symmetric, n_edges, sparsity

best_tau = None
best_A = None
best_edges = 0
best_sparsity = 0
for tau in threshold_range:
    A_pearson, edges_pearson, sparsity_pearson = get_adjacency_matrix(P_pearson, tau)
    if target_sparsity[0] <= sparsity_pearson <= target_sparsity[1]:
        best_tau = tau
        best_A = A_pearson
        best_edges = edges_pearson
        best_sparsity = sparsity_pearson
        break
    elif abs(sparsity_pearson - (target_sparsity[0] + target_sparsity[1]) / 2) < abs(best_sparsity - (target_sparsity[0] + target_sparsity[1]) / 2):
        best_tau = tau
        best_A = A_pearson
        best_edges = edges_pearson
        best_sparsity = sparsity_pearson

# Step 4: Validate final adjacency matrix
def validate_adjacency_matrix(A, label="", tau_used=None):
    n_nodes = A.shape[0]
    n_edges = np.sum(A) // 2
    sparsity = np.sum(A == 0) / (n_nodes * n_nodes)
    is_symmetric = np.array_equal(A, A.T)

    print(f"\nFinal Adjacency Matrix Validation ({label}, tau = {tau_used:.3f}):")
    print(f"Total number of nodes: {n_nodes} (should be 88)")
    print(f"Total number of edges: {n_edges}")
    print(f"Sparsity: {sparsity:.4f}")
    print(f"Is symmetric: {is_symmetric} (should be True)")

validate_adjacency_matrix(best_A, label="pearson", tau_used=best_tau)

# Convert to TensorFlow tensor
A_tf = tf.convert_to_tensor(best_A, dtype=tf.float32)

# Save adjacency matrix
np.save("adjacency_matrix_final.npy", best_A)
print("Adjacency matrix saved as adjacency_matrix_final.npy")
# Out:
# Found 37993 training piano-roll segments
# Processing up to 37993 segments for efficiency
# Processing piano-roll 0/37993
# Processing piano-roll 1000/37993
# Processing piano-roll 2000/37993
# Processing piano-roll 3000/37993
# Processing piano-roll 4000/37993
# Processing piano-roll 5000/37993
# Processing piano-roll 6000/37993
# Processing piano-roll 7000/37993
# Processing piano-roll 8000/37993
# Processing piano-roll 9000/37993
# Processing piano-roll 10000/37993
# Processing piano-roll 11000/37993
# Processing piano-roll 12000/37993
# Processing piano-roll 13000/37993
# Processing piano-roll 14000/37993
# Processing piano-roll 15000/37993
# Processing piano-roll 16000/37993
# Processing piano-roll 17000/37993
# Processing piano-roll 18000/37993
# Processing piano-roll 19000/37993
# Processing piano-roll 20000/37993
# Processing piano-roll 21000/37993
# Processing piano-roll 22000/37993
# Processing piano-roll 23000/37993
# Processing piano-roll 24000/37993
# Processing piano-roll 25000/37993
# Processing piano-roll 26000/37993
# Processing piano-roll 27000/37993
# Processing piano-roll 28000/37993
# Processing piano-roll 29000/37993
# Processing piano-roll 30000/37993
# Processing piano-roll 31000/37993
# Processing piano-roll 32000/37993
# Processing piano-roll 33000/37993
# Processing piano-roll 34000/37993
# Processing piano-roll 35000/37993
# Processing piano-roll 36000/37993
# Processing piano-roll 37000/37993
#
# Pearson Correlation Matrix Statistics:
# Min value: -0.0756
# Max value: 0.4251
# Mean value: 0.0430
#
# Final Adjacency Matrix Validation (pearson, tau = 0.180):
# Total number of nodes: 88 (should be 88)
# Total number of edges: 223
# Sparsity: 0.9424
# Is symmetric: True (should be True)
# Adjacency matrix saved as adjacency_matrix_final.npy

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model, metrics, callbacks
from pathlib import Path
import mir_eval
from sklearn.metrics import precision_recall_fscore_support

# Parameters
n_pitches = 88
n_mels = 229
frames_per_segment = 480
d = 88
d_prime = 768
hop_length = 512
sr = 22050

# Custom Learning Rate Schedule with Warmup
class WarmupDecaySchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, initial_lr, target_lr, warmup_steps, decay_steps, decay_rate):
        super(WarmupDecaySchedule, self).__init__()
        self.initial_lr = tf.cast(initial_lr, tf.float32)
        self.target_lr = tf.cast(target_lr, tf.float32)
        self.warmup_steps = tf.cast(warmup_steps, tf.float32)
        self.decay_steps = tf.cast(decay_steps, tf.float32)
        self.decay_rate = tf.cast(decay_rate, tf.float32)

    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warmup_lr = self.initial_lr + (self.target_lr - self.initial_lr) * (step / self.warmup_steps)
        warmup_lr = tf.minimum(self.target_lr, warmup_lr)
        decay_steps = tf.maximum(step - self.warmup_steps, 0.0)
        decay_lr = self.target_lr * tf.pow(self.decay_rate, decay_steps / self.decay_steps)
        lr = tf.where(step <= self.warmup_steps, warmup_lr, decay_lr)
        return lr

    def get_config(self):
        return {
            "initial_lr": self.initial_lr,
            "target_lr": self.target_lr,
            "warmup_steps": self.warmup_steps,
            "decay_steps": self.decay_steps,
            "decay_rate": self.decay_rate
        }

# Load and normalize adjacency matrix
A = np.load("adjacency_matrix_final.npy")
A = A + np.eye(n_pitches) + 0.5
row_sums = np.sum(A, axis=1, keepdims=True)
row_sums = np.where(row_sums == 0, 1e-8, row_sums)
A = A / row_sums
A = np.nan_to_num(A, nan=0.0)
A_tf = tf.convert_to_tensor(A, dtype=tf.float32)
if np.any(np.isnan(A_tf.numpy())):
    raise ValueError("Adjacency matrix A_tf contains NaN values after normalization")

# Load precomputed mel-spectrograms and piano-rolls
mel_train_dir = Path("./preprocessed_output_all_480_minimal/mel_spectrograms/train")
piano_roll_train_dir = Path("./preprocessed_output_all_480_minimal/piano_rolls/train")
mel_files = sorted(list(mel_train_dir.glob("*.npy")))
piano_roll_files = sorted(list(piano_roll_train_dir.glob("*_piano_roll.npy")))

print(f"Number of mel files: {len(mel_files)}, Number of piano-roll files: {len(piano_roll_files)}")
if not mel_files or not piano_roll_files:
    raise ValueError("No files found in mel_spectrograms or piano_rolls directories.")
if len(mel_files) != len(piano_roll_files):
    raise ValueError(f"Mismatch in number of mel files ({len(mel_files)}) and piano-roll files ({len(piano_roll_files)}).")

spectrograms = []
labels = []
for mel_file, pr_file in zip(mel_files[:1000], piano_roll_files[:1000]):
    mel_spec = np.load(mel_file)
    if mel_spec.shape != (n_mels, frames_per_segment):
        raise ValueError(f"Mel-spectrogram shape {mel_spec.shape} does not match expected ({n_mels}, {frames_per_segment})")
    mel_spec = (mel_spec - mel_spec.min()) / (mel_spec.max() - mel_spec.min() + 1e-8)
    spectrograms.append(mel_spec)
    pr = np.load(pr_file)
    if pr.size == 0 or np.all(pr == 0):
        print(f"Warning: Skipping invalid piano-roll file {pr_file} (empty or all zeros)")
        continue
    pr = (pr > 0).astype(np.float32)
    labels.append(pr)

spectrograms = np.array(spectrograms)
labels = np.array(labels)

print(f"Number of loaded spectrograms: {len(spectrograms)}, Number of loaded labels: {len(labels)}")
if len(spectrograms) == 0 or len(labels) == 0:
    raise ValueError("No valid samples loaded. Check your data files or subset size.")

num_positives = np.sum(labels == 1)
num_negatives = np.sum(labels == 0)
print(f"Number of positive labels: {num_positives}, Number of negative labels: {num_negatives}")
if num_positives == 0:
    print("Warning: No positive labels found in the dataset. Setting pos_weight to a default value.")
    pos_weight = 2.0
else:
    pos_weight = num_negatives / num_positives
    pos_weight = min(pos_weight * 0.5, 2.0)
print(f"Computed pos_weight: {pos_weight}")

# Custom Layers
class ClipLayer(layers.Layer):
    def __init__(self, min_value, max_value, **kwargs):
        super(ClipLayer, self).__init__(**kwargs)
        self.min_value = min_value
        self.max_value = max_value

    def call(self, inputs):
        return tf.clip_by_value(inputs, self.min_value, self.max_value)

class TransposeLayer(layers.Layer):
    def __init__(self, perm, **kwargs):
        super(TransposeLayer, self).__init__(**kwargs)
        self.perm = perm

    def call(self, inputs):
        return tf.transpose(inputs, perm=self.perm)

class DotProductLayer(layers.Layer):
    def __init__(self, **kwargs):
        super(DotProductLayer, self).__init__(**kwargs)

    def call(self, inputs):
        W, x = inputs
        return tf.matmul(W, x)

# Custom Focal Loss
def focal_loss_with_class_weight(gamma=1.5, alpha=0.8, pos_weight=2.0):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1.0 - tf.keras.backend.epsilon())
        cross_entropy = -y_true * tf.math.log(y_pred) - (1 - y_true) * tf.math.log(1 - y_pred)
        class_weight = y_true * pos_weight + (1 - y_true) * 1.0
        weight = alpha * y_true * tf.pow(1 - y_pred, gamma) + (1 - alpha) * (1 - y_true) * tf.pow(y_pred, gamma)
        return tf.reduce_mean(class_weight * weight * cross_entropy)
    return focal_loss_fixed

# Custom Metrics
class Precision(metrics.Metric):
    def __init__(self, threshold=0.3, name='precision', **kwargs):
        super(Precision, self).__init__(name=name, **kwargs)
        self.threshold = threshold
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.false_positives = self.add_weight(name='fp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.bool)
        y_pred = tf.cast(y_pred > self.threshold, tf.bool)
        tp = tf.reduce_sum(tf.cast(tf.logical_and(y_true, y_pred), tf.float32))
        fp = tf.reduce_sum(tf.cast(tf.logical_and(tf.logical_not(y_true), y_pred), tf.float32))
        self.true_positives.assign_add(tp)
        self.false_positives.assign_add(fp)

    def result(self):
        return self.true_positives / (self.true_positives + self.false_positives + tf.keras.backend.epsilon())

    def reset_state(self):
        self.true_positives.assign(0.)
        self.false_positives.assign(0.)

class Recall(metrics.Metric):
    def __init__(self, threshold=0.3, name='recall', **kwargs):
        super(Recall, self).__init__(name=name, **kwargs)
        self.threshold = threshold
        self.true_positives = self.add_weight(name='tp', initializer='zeros')
        self.false_negatives = self.add_weight(name='fn', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.bool)
        y_pred = tf.cast(y_pred > self.threshold, tf.bool)
        tp = tf.reduce_sum(tf.cast(tf.logical_and(y_true, y_pred), tf.float32))
        fn = tf.reduce_sum(tf.cast(tf.logical_and(y_true, tf.logical_not(y_pred)), tf.float32))
        self.true_positives.assign_add(tp)
        self.false_negatives.assign_add(fn)

    def result(self):
        return self.true_positives / (self.true_positives + self.false_negatives + tf.keras.backend.epsilon())

    def reset_state(self):
        self.true_positives.assign(0.)
        self.false_negatives.assign(0.)

class F1Score(metrics.Metric):
    def __init__(self, threshold=0.3, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.threshold = threshold
        self.precision = Precision(threshold=self.threshold)
        self.recall = Recall(threshold=self.threshold)

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        return 2 * ((p * r) / (p + r + tf.keras.backend.epsilon()))

    def reset_state(self):
        self.precision.reset_state()
        self.recall.reset_state()

# Build CNN+LSTM branch
def build_cnn_lstm():
    inputs = layers.Input(shape=(n_mels, frames_per_segment, 1))
    x = layers.Conv2D(32, (3, 1), activation='relu', padding='same')(inputs)
    x = layers.MaxPooling2D((2, 1))(x)
    x = layers.Conv2D(57, (3, 1), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2, 1))(x)
    x = layers.Reshape((frames_per_segment, -1))(x)
    x = layers.Bidirectional(layers.LSTM(128, return_sequences=True))(x)
    x = layers.Dropout(0.5)(x)
    features = layers.Dense(d_prime, activation=None)(x)
    features = ClipLayer(min_value=-1e6, max_value=1e6)(features)
    pred = layers.Dense(n_pitches, activation='sigmoid')(features)
    pred = TransposeLayer(perm=[0, 2, 1])(pred)
    return Model(inputs=inputs, outputs={'cnn_lstm_features': features, 'cnn_lstm_pred': pred}, name="cnn_lstm")

# Custom GCN Layer
class GCNLayer(layers.Layer):
    def __init__(self, units, activation="relu", **kwargs):
        super(GCNLayer, self).__init__(**kwargs)
        self.units = units
        self.activation = tf.keras.activations.get(activation)
        self.dense = layers.Dense(units, activation=activation, use_bias=True)
        self.layer_norm = layers.LayerNormalization()

    def call(self, inputs):
        node_features, adjacency = inputs
        x = self.dense(node_features)
        x_gcn = tf.matmul(adjacency, x)
        x = x + x_gcn
        x = self.layer_norm(x)
        x = ClipLayer(min_value=-1e6, max_value=1e6)(x)
        return x

# Build GCN branch
def build_gcn(scale):
    node_features = layers.Input(shape=(n_pitches, d), name="node_features")
    adjacency = layers.Input(shape=(n_pitches, n_pitches), name="adjacency", dtype=tf.float32)
    x = GCNLayer(d_prime)([node_features, adjacency])
    x = GCNLayer(d_prime)([x, adjacency])
    x = GCNLayer(d_prime)([x, adjacency])
    W = x
    W = layers.Dense(d_prime, activation='relu')(W)
    W = W * scale
    tf.print("GCN Output W (first batch, first 10 values): ", W[0, :10, 0])
    return Model(inputs=[node_features, adjacency], outputs={'gcn_pred': W}, name="gcn")

# Combined CR-GCN model
class CRGCN(Model):
    def __init__(self, A):
        super(CRGCN, self).__init__()
        self.cnn_lstm = build_cnn_lstm()
        self.scale = tf.Variable(1.0, trainable=True, name='gcn_output_scale', dtype=tf.float32)  # Increased initial value
        self.gcn = build_gcn(self.scale)
        self.A = A
        self.transpose_layer = TransposeLayer(perm=[0, 2, 1])
        self.dot_product_layer = DotProductLayer()
        self.H0 = self.add_weight(
            name="H0",
            shape=(n_pitches, d),
            initializer=tf.keras.initializers.RandomNormal(mean=0.1, stddev=0.05),
            trainable=True
        )
        self.H0_transform = layers.Dense(d, activation='relu')
        self.feature_projection = layers.Dense(n_pitches, activation='relu')
        self.feature_projection_d_prime = layers.Dense(d_prime, activation='relu')

    def call(self, inputs, training=False):
        spectrogram = inputs
        cnn_lstm_outputs = self.cnn_lstm(spectrogram)
        x = cnn_lstm_outputs['cnn_lstm_features']
        cnn_lstm_pred = cnn_lstm_outputs['cnn_lstm_pred']
        cnn_lstm_features_projected = self.feature_projection(x)
        cnn_lstm_features_projected = tf.transpose(cnn_lstm_features_projected, perm=[0, 2, 1])
        cnn_lstm_features_projected = self.feature_projection_d_prime(cnn_lstm_features_projected)
        
        x = self.transpose_layer(x)
        batch_size = tf.shape(spectrogram)[0]
        H0_expanded = tf.expand_dims(self.H0, 0)
        H0_tiled = tf.tile(H0_expanded, [batch_size, 1, 1])
        H0_transformed = self.H0_transform(H0_tiled)
        A_tiled = tf.tile(tf.expand_dims(self.A, 0), [batch_size, 1, 1])
        gcn_outputs = self.gcn([H0_transformed, A_tiled])
        W = gcn_outputs['gcn_pred']
        W = W + cnn_lstm_features_projected
        W = tf.debugging.check_numerics(W, "GCN output contains NaN or Inf")
        gcn_pred = self.dot_product_layer([W, x])
        gcn_pred = layers.Activation('sigmoid')(gcn_pred)
        
        if training:
            gcn_loss = tf.reduce_mean(tf.square(W)) * 0.01  # Auxiliary loss
            gcn_loss = tf.debugging.check_numerics(gcn_loss, "Auxiliary GCN loss contains NaN or Inf")
            self.add_loss(gcn_loss)
        return gcn_pred

    def build(self, input_shape):
        super(CRGCN, self).build(input_shape)
        self.cnn_lstm.build(input_shape)
        self.gcn.build([(None, n_pitches, d), (None, n_pitches, n_pitches)])

# Instantiate and compile
model = CRGCN(A_tf)
model.build(input_shape=(None, n_mels, frames_per_segment, 1))

# Learning rate schedule
steps_per_epoch = len(spectrograms) // 64
warmup_epochs = 15
warmup_steps = steps_per_epoch * warmup_epochs
lr_schedule = WarmupDecaySchedule(
    initial_lr=0.00001,
    target_lr=0.0001,
    warmup_steps=warmup_steps,
    decay_steps=3000,
    decay_rate=0.95
)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule, clipnorm=1.0)

model.compile(
    optimizer=optimizer,
    loss=focal_loss_with_class_weight(gamma=1.5, alpha=0.8, pos_weight=2.0),
    metrics=[Precision(threshold=0.3), Recall(threshold=0.3), F1Score(threshold=0.3), 'accuracy']
)

# Debugging callback
class DebugCallback(callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        batch = spectrograms[:16][..., np.newaxis]
        with tf.GradientTape() as tape:
            predictions = self.model(batch, training=True)
            loss = self.model.compute_loss(batch, labels[:16], predictions, None, training=True)
        grads = tape.gradient(loss, self.model.trainable_variables)
        gcn_grads = [g for g, v in zip(grads, self.model.trainable_variables) if 'gcn' in v.name]
        print(f"\nEpoch {epoch + 1} - Prediction Stats:")
        preds = self.model.predict(batch, verbose=0)
        print(f"Mean prediction: {np.mean(preds):.4f}")
        print(f"Min prediction: {np.min(preds):.4f}")
        print(f"Max prediction: {np.max(preds):.4f}")
        print(f"Percentage of predictions > 0.5: {np.mean(preds > 0.5) * 100:.2f}%")
        print(f"Percentage of predictions > 0.3: {np.mean(preds > 0.3) * 100:.2f}%")
        print("GCN Gradients Present:", any(g is not None for g in gcn_grads))

# Callbacks
checkpoint = callbacks.ModelCheckpoint(
    'best_model.keras',
    monitor='val_f1_score',
    mode='max',
    save_best_only=True,
    verbose=1
)

early_stopping = callbacks.EarlyStopping(
    monitor='val_f1_score',
    patience=20,
    mode='max',
    restore_best_weights=True,
    verbose=1
)

# Train for 100 epochs
spectrograms = spectrograms[..., np.newaxis]
history = model.fit(
    spectrograms,
    labels,
    epochs=100,
    batch_size=64,
    validation_split=0.2,
    callbacks=[DebugCallback(), checkpoint, early_stopping],
    verbose=1
)

# Updated post-processing functions
def smooth_predictions(predictions, kernel_size=3):
    kernel = np.ones(kernel_size) / kernel_size
    smoothed = np.zeros_like(predictions)
    for b in range(predictions.shape[0]):
        for p in range(predictions.shape[1]):
            smoothed[b, p, :] = np.convolve(predictions[b, p, :], kernel, mode='same')
    return smoothed

def filter_short_notes(predictions, threshold=0.3, min_duration_frames=12):
    filtered = np.zeros_like(predictions)
    for b in range(predictions.shape[0]):
        for p in range(predictions.shape[1]):
            binary = predictions[b, p, :] > threshold
            diff = np.diff(binary, prepend=0)
            onsets = np.where(diff == 1)[0]
            offsets = np.where(diff == -1)[0]
            for onset, offset in zip(onsets, offsets):
                if offset - onset >= min_duration_frames:
                    filtered[b, p, onset:offset] = 1.0
    return filtered

def piano_roll_to_notes(piano_roll, fs=22050, hop_length=512, threshold=0.3, min_duration=0.05):
    notes = []
    piano_roll = np.pad(piano_roll, ((0, 0), (1, 0)), mode='constant')
    for pitch in range(n_pitches):
        onsets = np.where(np.diff(piano_roll[pitch] > threshold, prepend=False) == 1)[0]
        offsets = np.where(np.diff(piano_roll[pitch] > threshold, prepend=False) == -1)[0]
        for onset, offset in zip(onsets, offsets):
            onset_time = onset * hop_length / fs
            offset_time = offset * hop_length / fs
            duration = offset_time - onset_time
            if duration >= min_duration and offset_time > onset_time:
                notes.append((onset_time, offset_time, pitch + 21))
    return np.array(notes) if notes else np.empty((0, 3))

# Find optimal threshold
val_indices = np.random.choice(len(spectrograms), int(0.2 * len(spectrograms)), replace=False)
val_spectrograms = spectrograms[val_indices]
val_labels = labels[val_indices]

val_predictions = model.predict(val_spectrograms)
val_predictions_probs = smooth_predictions(val_predictions)
val_predictions_filtered = filter_short_notes(val_predictions_probs)

thresholds = np.arange(0.2, 0.5, 0.05)
best_f1 = 0
best_threshold = 0.3
for thresh in thresholds:
    val_preds_binary = (val_predictions_filtered > thresh).astype(int)
    precision, recall, f1, _ = precision_recall_fscore_support(val_labels.flatten(), val_preds_binary.flatten(), average='binary', zero_division=0)
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = thresh

print(f"Optimal threshold: {best_threshold}, F1-score: {best_f1}")

# Evaluate
val_predictions_binary = (val_predictions_filtered > best_threshold).astype(int)
val_labels_flat = val_labels.flatten()
val_preds_flat = val_predictions_binary.flatten()
precision, recall, f1, _ = precision_recall_fscore_support(val_labels_flat, val_preds_flat, average='binary', zero_division=0)
print(f"Frame-level Precision: {precision:.4f}")
print(f"Frame-level Recall: {recall:.4f}")
print(f"Frame-level F1-score: {f1:.4f}")

ref_notes = [piano_roll_to_notes(pr, fs=sr, hop_length=hop_length, threshold=best_threshold, min_duration=0.05) for pr in val_labels]
est_notes = [piano_roll_to_notes(pr, fs=sr, hop_length=hop_length, threshold=best_threshold, min_duration=0.05) for pr in val_predictions_binary]
ref_intervals = [notes[:, :2] if len(notes) > 0 else np.empty((0, 2)) for notes in ref_notes]
ref_pitches = [notes[:, 2] if len(notes) > 0 else np.array([]) for notes in ref_notes]
est_intervals = [notes[:, :2] if len(notes) > 0 else np.empty((0, 2)) for notes in est_notes]
est_pitches = [notes[:, 2] if len(notes) > 0 else np.array([]) for notes in est_notes]

note_precision, note_recall, note_f1 = 0, 0, 0
num_samples = len(ref_intervals)
valid_samples = 0
for i in range(num_samples):
    if len(ref_intervals[i]) == 0 and len(est_intervals[i]) == 0:
        continue
    scores = mir_eval.transcription.evaluate(
        ref_intervals[i], ref_pitches[i], est_intervals[i], est_pitches[i],
        onset_tolerance=0.05, offset_ratio=0.2
    )
    note_precision += scores['Precision']
    note_recall += scores['Recall']
    note_f1 += scores['F-measure']
    valid_samples += 1

if valid_samples > 0:
    note_precision /= valid_samples
    note_recall /= valid_samples
    note_f1 /= valid_samples
else:
    note_precision, note_recall, note_f1 = 0.0, 0.0, 0.0

print(f"Note-level Precision: {note_precision:.4f}")
print(f"Note-level Recall: {note_recall:.4f}")
print(f"Note-level F1-score: {note_f1:.4f}")

model.save("cr_gcn_model.keras")
# Out:
# Number of mel files: 37993, Number of piano-roll files: 37993
# Number of loaded spectrograms: 1000, Number of loaded labels: 1000
# Number of positive labels: 2450463, Number of negative labels: 39789537
# Computed pos_weight: 2.0
# GCN Output W (first batch, first 10 values):  <KerasTensor shape=(10,), dtype=float32, sparse=False, name=keras_tensor_602>
# Epoch 1/100
# /nfsshare/selva/.local/lib/python3.9/site-packages/keras/src/optimizers/base_optimizer.py:774: UserWarning: Gradients do not exist for variables ['dense_185/kernel', 'dense_185/bias'] when minimizing the loss. If using `model.compile()`, did you forget to provide a `loss` argument?
#   warnings.warn(
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0020 - f1_score: 0.1081 - loss: 0.1120 - precision: 0.0580 - recall: 0.7892
# Epoch 1 - Prediction Stats:
# Mean prediction: 0.3845
# Min prediction: 0.1660
# Max prediction: 0.5244
# Percentage of predictions > 0.5: 0.10%
# Percentage of predictions > 0.3: 90.60%
# GCN Gradients Present: False
#
# Epoch 1: val_f1_score improved from -inf to 0.10794, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.0019 - f1_score: 0.1081 - loss: 0.1113 - precision: 0.0581 - recall: 0.7892 - val_accuracy: 4.5455e-04 - val_f1_score: 0.1079 - val_loss: 0.0661 - val_precision: 0.0572 - val_recall: 0.9467
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0022 - f1_score: 0.1087 - loss: 0.0811 - precision: 0.0581 - recall: 0.8483
# Epoch 2 - Prediction Stats:
# Mean prediction: 0.4516
# Min prediction: 0.2878
# Max prediction: 0.5781
# Percentage of predictions > 0.5: 3.43%
# Percentage of predictions > 0.3: 100.00%
# GCN Gradients Present: False
#
# Epoch 2: val_f1_score did not improve from 0.10794
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0022 - f1_score: 0.1089 - loss: 0.0809 - precision: 0.0581 - recall: 0.8504 - val_accuracy: 0.0022 - val_f1_score: 0.1068 - val_loss: 0.0631 - val_precision: 0.0564 - val_recall: 0.9998
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0018 - f1_score: 0.1112 - loss: 0.0713 - precision: 0.0591 - recall: 0.9444
# Epoch 3 - Prediction Stats:
# Mean prediction: 0.4357
# Min prediction: 0.2563
# Max prediction: 0.5918
# Percentage of predictions > 0.5: 1.54%
# Percentage of predictions > 0.3: 99.79%
# GCN Gradients Present: False
#
# Epoch 3: val_f1_score did not improve from 0.10794
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0018 - f1_score: 0.1113 - loss: 0.0712 - precision: 0.0591 - recall: 0.9451 - val_accuracy: 0.0022 - val_f1_score: 0.1070 - val_loss: 0.0616 - val_precision: 0.0565 - val_recall: 0.9993
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0019 - f1_score: 0.1117 - loss: 0.0668 - precision: 0.0592 - recall: 0.9830
# Epoch 4 - Prediction Stats:
# Mean prediction: 0.4196
# Min prediction: 0.1701
# Max prediction: 0.6250
# Percentage of predictions > 0.5: 2.04%
# Percentage of predictions > 0.3: 96.82%
# GCN Gradients Present: False
#
# Epoch 4: val_f1_score improved from 0.10794 to 0.10857, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.0019 - f1_score: 0.1118 - loss: 0.0667 - precision: 0.0593 - recall: 0.9831 - val_accuracy: 0.0037 - val_f1_score: 0.1086 - val_loss: 0.0599 - val_precision: 0.0574 - val_recall: 0.9973
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0048 - f1_score: 0.1160 - loss: 0.0644 - precision: 0.0616 - recall: 0.9882
# Epoch 5 - Prediction Stats:
# Mean prediction: 0.4179
# Min prediction: 0.0849
# Max prediction: 0.6730
# Percentage of predictions > 0.5: 11.89%
# Percentage of predictions > 0.3: 89.46%
# GCN Gradients Present: False
#
# Epoch 5: val_f1_score improved from 0.10857 to 0.11336, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.0047 - f1_score: 0.1161 - loss: 0.0644 - precision: 0.0617 - recall: 0.9880 - val_accuracy: 0.0045 - val_f1_score: 0.1134 - val_loss: 0.0585 - val_precision: 0.0601 - val_recall: 0.9922
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0023 - f1_score: 0.1232 - loss: 0.0621 - precision: 0.0657 - recall: 0.9798
# Epoch 6 - Prediction Stats:
# Mean prediction: 0.4109
# Min prediction: 0.0350
# Max prediction: 0.6864
# Percentage of predictions > 0.5: 20.57%
# Percentage of predictions > 0.3: 83.20%
# GCN Gradients Present: False
#
# Epoch 6: val_f1_score improved from 0.11336 to 0.11930, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0023 - f1_score: 0.1233 - loss: 0.0621 - precision: 0.0658 - recall: 0.9795 - val_accuracy: 0.0044 - val_f1_score: 0.1193 - val_loss: 0.0575 - val_precision: 0.0635 - val_recall: 0.9882
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0017 - f1_score: 0.1279 - loss: 0.0604 - precision: 0.0684 - recall: 0.9750
# Epoch 7 - Prediction Stats:
# Mean prediction: 0.4560
# Min prediction: 0.0295
# Max prediction: 0.7388
# Percentage of predictions > 0.5: 40.63%
# Percentage of predictions > 0.3: 85.19%
# GCN Gradients Present: False
#
# Epoch 7: val_f1_score did not improve from 0.11930
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0017 - f1_score: 0.1281 - loss: 0.0604 - precision: 0.0685 - recall: 0.9748 - val_accuracy: 0.0034 - val_f1_score: 0.1186 - val_loss: 0.0619 - val_precision: 0.0631 - val_recall: 0.9948
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0017 - f1_score: 0.1286 - loss: 0.0603 - precision: 0.0688 - recall: 0.9745
# Epoch 8 - Prediction Stats:
# Mean prediction: 0.3458
# Min prediction: 0.0068
# Max prediction: 0.5311
# Percentage of predictions > 0.5: 0.42%
# Percentage of predictions > 0.3: 73.25%
# GCN Gradients Present: False
#
# Epoch 8: val_f1_score improved from 0.11930 to 0.13158, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.0017 - f1_score: 0.1288 - loss: 0.0603 - precision: 0.0689 - recall: 0.9745 - val_accuracy: 0.0061 - val_f1_score: 0.1316 - val_loss: 0.0561 - val_precision: 0.0705 - val_recall: 0.9759
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0024 - f1_score: 0.1334 - loss: 0.0583 - precision: 0.0716 - recall: 0.9717
# Epoch 9 - Prediction Stats:
# Mean prediction: 0.3741
# Min prediction: 0.0058
# Max prediction: 0.6136
# Percentage of predictions > 0.5: 13.24%
# Percentage of predictions > 0.3: 74.85%
# GCN Gradients Present: False
#
# Epoch 9: val_f1_score did not improve from 0.13158
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0024 - f1_score: 0.1335 - loss: 0.0583 - precision: 0.0717 - recall: 0.9718 - val_accuracy: 0.0046 - val_f1_score: 0.1310 - val_loss: 0.0548 - val_precision: 0.0702 - val_recall: 0.9838
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0030 - f1_score: 0.1391 - loss: 0.0577 - precision: 0.0749 - recall: 0.9745
# Epoch 10 - Prediction Stats:
# Mean prediction: 0.3717
# Min prediction: 0.0052
# Max prediction: 0.5944
# Percentage of predictions > 0.5: 16.27%
# Percentage of predictions > 0.3: 73.37%
# GCN Gradients Present: False
#
# Epoch 10: val_f1_score improved from 0.13158 to 0.13575, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0030 - f1_score: 0.1391 - loss: 0.0576 - precision: 0.0749 - recall: 0.9745 - val_accuracy: 0.0095 - val_f1_score: 0.1358 - val_loss: 0.0539 - val_precision: 0.0729 - val_recall: 0.9832
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0034 - f1_score: 0.1418 - loss: 0.0556 - precision: 0.0765 - recall: 0.9716
# Epoch 11 - Prediction Stats:
# Mean prediction: 0.3879
# Min prediction: 0.0087
# Max prediction: 0.6017
# Percentage of predictions > 0.5: 33.67%
# Percentage of predictions > 0.3: 73.51%
# GCN Gradients Present: False
#
# Epoch 11: val_f1_score improved from 0.13575 to 0.13860, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0034 - f1_score: 0.1421 - loss: 0.0556 - precision: 0.0766 - recall: 0.9715 - val_accuracy: 0.0176 - val_f1_score: 0.1386 - val_loss: 0.0537 - val_precision: 0.0746 - val_recall: 0.9817
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0068 - f1_score: 0.1456 - loss: 0.0541 - precision: 0.0787 - recall: 0.9713
# Epoch 12 - Prediction Stats:
# Mean prediction: 0.3597
# Min prediction: 0.0128
# Max prediction: 0.5698
# Percentage of predictions > 0.5: 9.62%
# Percentage of predictions > 0.3: 70.67%
# GCN Gradients Present: False
#
# Epoch 12: val_f1_score improved from 0.13860 to 0.14669, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0070 - f1_score: 0.1459 - loss: 0.0542 - precision: 0.0789 - recall: 0.9711 - val_accuracy: 0.0034 - val_f1_score: 0.1467 - val_loss: 0.0527 - val_precision: 0.0794 - val_recall: 0.9621
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0140 - f1_score: 0.1521 - loss: 0.0555 - precision: 0.0825 - recall: 0.9667
# Epoch 13 - Prediction Stats:
# Mean prediction: 0.3697
# Min prediction: 0.0100
# Max prediction: 0.5716
# Percentage of predictions > 0.5: 29.12%
# Percentage of predictions > 0.3: 69.75%
# GCN Gradients Present: False
#
# Epoch 13: val_f1_score improved from 0.14669 to 0.15120, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0144 - f1_score: 0.1520 - loss: 0.0554 - precision: 0.0825 - recall: 0.9667 - val_accuracy: 0.0675 - val_f1_score: 0.1512 - val_loss: 0.0526 - val_precision: 0.0821 - val_recall: 0.9555
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0282 - f1_score: 0.1518 - loss: 0.0538 - precision: 0.0824 - recall: 0.9594
# Epoch 14 - Prediction Stats:
# Mean prediction: 0.3687
# Min prediction: 0.0163
# Max prediction: 0.5584
# Percentage of predictions > 0.5: 13.67%
# Percentage of predictions > 0.3: 72.16%
# GCN Gradients Present: False
#
# Epoch 14: val_f1_score did not improve from 0.15120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0281 - f1_score: 0.1518 - loss: 0.0538 - precision: 0.0824 - recall: 0.9599 - val_accuracy: 0.0347 - val_f1_score: 0.1459 - val_loss: 0.0525 - val_precision: 0.0789 - val_recall: 0.9690
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0289 - f1_score: 0.1522 - loss: 0.0535 - precision: 0.0826 - recall: 0.9655
# Epoch 15 - Prediction Stats:
# Mean prediction: 0.3873
# Min prediction: 0.0174
# Max prediction: 0.5707
# Percentage of predictions > 0.5: 35.11%
# Percentage of predictions > 0.3: 74.39%
# GCN Gradients Present: False
#
# Epoch 15: val_f1_score did not improve from 0.15120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0290 - f1_score: 0.1522 - loss: 0.0535 - precision: 0.0826 - recall: 0.9656 - val_accuracy: 0.0874 - val_f1_score: 0.1442 - val_loss: 0.0529 - val_precision: 0.0779 - val_recall: 0.9726
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0312 - f1_score: 0.1556 - loss: 0.0532 - precision: 0.0846 - recall: 0.9660
# Epoch 16 - Prediction Stats:
# Mean prediction: 0.4247
# Min prediction: 0.0362
# Max prediction: 0.5887
# Percentage of predictions > 0.5: 45.04%
# Percentage of predictions > 0.3: 81.33%
# GCN Gradients Present: False
#
# Epoch 16: val_f1_score did not improve from 0.15120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0309 - f1_score: 0.1555 - loss: 0.0532 - precision: 0.0846 - recall: 0.9657 - val_accuracy: 0.1028 - val_f1_score: 0.1330 - val_loss: 0.0548 - val_precision: 0.0713 - val_recall: 0.9923
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0249 - f1_score: 0.1487 - loss: 0.0543 - precision: 0.0805 - recall: 0.9747
# Epoch 17 - Prediction Stats:
# Mean prediction: 0.3753
# Min prediction: 0.0194
# Max prediction: 0.5389
# Percentage of predictions > 0.5: 18.28%
# Percentage of predictions > 0.3: 73.67%
# GCN Gradients Present: False
#
# Epoch 17: val_f1_score did not improve from 0.15120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0251 - f1_score: 0.1488 - loss: 0.0542 - precision: 0.0806 - recall: 0.9741 - val_accuracy: 0.0369 - val_f1_score: 0.1462 - val_loss: 0.0524 - val_precision: 0.0791 - val_recall: 0.9686
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0217 - f1_score: 0.1516 - loss: 0.0531 - precision: 0.0823 - recall: 0.9683
# Epoch 18 - Prediction Stats:
# Mean prediction: 0.3796
# Min prediction: 0.0224
# Max prediction: 0.5426
# Percentage of predictions > 0.5: 25.70%
# Percentage of predictions > 0.3: 74.36%
# GCN Gradients Present: False
#
# Epoch 18: val_f1_score did not improve from 0.15120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0218 - f1_score: 0.1517 - loss: 0.0531 - precision: 0.0823 - recall: 0.9682 - val_accuracy: 0.0719 - val_f1_score: 0.1434 - val_loss: 0.0525 - val_precision: 0.0774 - val_recall: 0.9747
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0444 - f1_score: 0.1550 - loss: 0.0540 - precision: 0.0842 - recall: 0.9690
# Epoch 19 - Prediction Stats:
# Mean prediction: 0.3781
# Min prediction: 0.0206
# Max prediction: 0.5494
# Percentage of predictions > 0.5: 27.48%
# Percentage of predictions > 0.3: 72.23%
# GCN Gradients Present: False
#
# Epoch 19: val_f1_score did not improve from 0.15120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0443 - f1_score: 0.1548 - loss: 0.0540 - precision: 0.0841 - recall: 0.9689 - val_accuracy: 0.0081 - val_f1_score: 0.1452 - val_loss: 0.0526 - val_precision: 0.0785 - val_recall: 0.9710
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0356 - f1_score: 0.1517 - loss: 0.0536 - precision: 0.0823 - recall: 0.9664
# Epoch 20 - Prediction Stats:
# Mean prediction: 0.3797
# Min prediction: 0.0183
# Max prediction: 0.5525
# Percentage of predictions > 0.5: 36.99%
# Percentage of predictions > 0.3: 72.05%
# GCN Gradients Present: False
#
# Epoch 20: val_f1_score did not improve from 0.15120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0357 - f1_score: 0.1518 - loss: 0.0535 - precision: 0.0824 - recall: 0.9662 - val_accuracy: 0.0325 - val_f1_score: 0.1479 - val_loss: 0.0527 - val_precision: 0.0800 - val_recall: 0.9692
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0298 - f1_score: 0.1492 - loss: 0.0529 - precision: 0.0808 - recall: 0.9689
# Epoch 21 - Prediction Stats:
# Mean prediction: 0.3785
# Min prediction: 0.0189
# Max prediction: 0.5496
# Percentage of predictions > 0.5: 33.16%
# Percentage of predictions > 0.3: 72.38%
# GCN Gradients Present: False
#
# Epoch 21: val_f1_score did not improve from 0.15120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0299 - f1_score: 0.1493 - loss: 0.0529 - precision: 0.0809 - recall: 0.9691 - val_accuracy: 0.0458 - val_f1_score: 0.1465 - val_loss: 0.0525 - val_precision: 0.0793 - val_recall: 0.9677
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0365 - f1_score: 0.1525 - loss: 0.0532 - precision: 0.0828 - recall: 0.9634
# Epoch 22 - Prediction Stats:
# Mean prediction: 0.3655
# Min prediction: 0.0138
# Max prediction: 0.5407
# Percentage of predictions > 0.5: 30.22%
# Percentage of predictions > 0.3: 69.46%
# GCN Gradients Present: False
#
# Epoch 22: val_f1_score improved from 0.15120 to 0.15227, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.0360 - f1_score: 0.1525 - loss: 0.0532 - precision: 0.0828 - recall: 0.9638 - val_accuracy: 0.0156 - val_f1_score: 0.1523 - val_loss: 0.0525 - val_precision: 0.0827 - val_recall: 0.9558
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0270 - f1_score: 0.1554 - loss: 0.0527 - precision: 0.0845 - recall: 0.9623
# Epoch 23 - Prediction Stats:
# Mean prediction: 0.3856
# Min prediction: 0.0202
# Max prediction: 0.5493
# Percentage of predictions > 0.5: 33.19%
# Percentage of predictions > 0.3: 74.37%
# GCN Gradients Present: False
#
# Epoch 23: val_f1_score did not improve from 0.15227
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0276 - f1_score: 0.1553 - loss: 0.0528 - precision: 0.0845 - recall: 0.9625 - val_accuracy: 0.0264 - val_f1_score: 0.1450 - val_loss: 0.0527 - val_precision: 0.0783 - val_recall: 0.9736
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0397 - f1_score: 0.1523 - loss: 0.0526 - precision: 0.0826 - recall: 0.9697
# Epoch 24 - Prediction Stats:
# Mean prediction: 0.3739
# Min prediction: 0.0174
# Max prediction: 0.5415
# Percentage of predictions > 0.5: 31.48%
# Percentage of predictions > 0.3: 71.73%
# GCN Gradients Present: False
#
# Epoch 24: val_f1_score did not improve from 0.15227
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0395 - f1_score: 0.1523 - loss: 0.0526 - precision: 0.0826 - recall: 0.9696 - val_accuracy: 0.0082 - val_f1_score: 0.1478 - val_loss: 0.0525 - val_precision: 0.0800 - val_recall: 0.9668
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0184 - f1_score: 0.1522 - loss: 0.0527 - precision: 0.0826 - recall: 0.9665
# Epoch 25 - Prediction Stats:
# Mean prediction: 0.3682
# Min prediction: 0.0146
# Max prediction: 0.5367
# Percentage of predictions > 0.5: 30.60%
# Percentage of predictions > 0.3: 69.80%
# GCN Gradients Present: False
#
# Epoch 25: val_f1_score did not improve from 0.15227
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0186 - f1_score: 0.1521 - loss: 0.0527 - precision: 0.0826 - recall: 0.9667 - val_accuracy: 0.0085 - val_f1_score: 0.1505 - val_loss: 0.0524 - val_precision: 0.0816 - val_recall: 0.9599
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0291 - f1_score: 0.1586 - loss: 0.0531 - precision: 0.0864 - recall: 0.9615
# Epoch 26 - Prediction Stats:
# Mean prediction: 0.3742
# Min prediction: 0.0154
# Max prediction: 0.5415
# Percentage of predictions > 0.5: 31.26%
# Percentage of predictions > 0.3: 72.37%
# GCN Gradients Present: False
#
# Epoch 26: val_f1_score did not improve from 0.15227
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0293 - f1_score: 0.1583 - loss: 0.0531 - precision: 0.0863 - recall: 0.9616 - val_accuracy: 0.0048 - val_f1_score: 0.1473 - val_loss: 0.0525 - val_precision: 0.0797 - val_recall: 0.9681
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0178 - f1_score: 0.1516 - loss: 0.0533 - precision: 0.0822 - recall: 0.9710
# Epoch 27 - Prediction Stats:
# Mean prediction: 0.3934
# Min prediction: 0.0233
# Max prediction: 0.5530
# Percentage of predictions > 0.5: 37.08%
# Percentage of predictions > 0.3: 77.14%
# GCN Gradients Present: False
#
# Epoch 27: val_f1_score did not improve from 0.15227
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0177 - f1_score: 0.1518 - loss: 0.0533 - precision: 0.0823 - recall: 0.9706 - val_accuracy: 0.0066 - val_f1_score: 0.1408 - val_loss: 0.0530 - val_precision: 0.0758 - val_recall: 0.9814
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0220 - f1_score: 0.1504 - loss: 0.0536 - precision: 0.0815 - recall: 0.9761
# Epoch 28 - Prediction Stats:
# Mean prediction: 0.3821
# Min prediction: 0.0183
# Max prediction: 0.5424
# Percentage of predictions > 0.5: 33.89%
# Percentage of predictions > 0.3: 73.39%
# GCN Gradients Present: False
#
# Epoch 28: val_f1_score did not improve from 0.15227
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0222 - f1_score: 0.1506 - loss: 0.0536 - precision: 0.0816 - recall: 0.9755 - val_accuracy: 0.0094 - val_f1_score: 0.1452 - val_loss: 0.0526 - val_precision: 0.0784 - val_recall: 0.9767
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0318 - f1_score: 0.1498 - loss: 0.0521 - precision: 0.0811 - recall: 0.9751
# Epoch 29 - Prediction Stats:
# Mean prediction: 0.3868
# Min prediction: 0.0192
# Max prediction: 0.5485
# Percentage of predictions > 0.5: 35.29%
# Percentage of predictions > 0.3: 75.68%
# GCN Gradients Present: False
#
# Epoch 29: val_f1_score did not improve from 0.15227
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0321 - f1_score: 0.1500 - loss: 0.0521 - precision: 0.0813 - recall: 0.9747 - val_accuracy: 0.0159 - val_f1_score: 0.1433 - val_loss: 0.0527 - val_precision: 0.0773 - val_recall: 0.9770
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0265 - f1_score: 0.1519 - loss: 0.0535 - precision: 0.0824 - recall: 0.9731
# Epoch 30 - Prediction Stats:
# Mean prediction: 0.3817
# Min prediction: 0.0187
# Max prediction: 0.5514
# Percentage of predictions > 0.5: 34.81%
# Percentage of predictions > 0.3: 72.00%
# GCN Gradients Present: False
#
# Epoch 30: val_f1_score did not improve from 0.15227
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0265 - f1_score: 0.1520 - loss: 0.0535 - precision: 0.0824 - recall: 0.9728 - val_accuracy: 0.0039 - val_f1_score: 0.1465 - val_loss: 0.0526 - val_precision: 0.0792 - val_recall: 0.9720
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0262 - f1_score: 0.1518 - loss: 0.0527 - precision: 0.0824 - recall: 0.9716
# Epoch 31 - Prediction Stats:
# Mean prediction: 0.3920
# Min prediction: 0.0257
# Max prediction: 0.5436
# Percentage of predictions > 0.5: 33.85%
# Percentage of predictions > 0.3: 77.69%
# GCN Gradients Present: False
#
# Epoch 31: val_f1_score did not improve from 0.15227
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0261 - f1_score: 0.1519 - loss: 0.0527 - precision: 0.0824 - recall: 0.9714 - val_accuracy: 0.0109 - val_f1_score: 0.1394 - val_loss: 0.0528 - val_precision: 0.0750 - val_recall: 0.9855
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0311 - f1_score: 0.1531 - loss: 0.0528 - precision: 0.0831 - recall: 0.9711
# Epoch 32 - Prediction Stats:
# Mean prediction: 0.3886
# Min prediction: 0.0239
# Max prediction: 0.5538
# Percentage of predictions > 0.5: 34.07%
# Percentage of predictions > 0.3: 75.27%
# GCN Gradients Present: False
#
# Epoch 32: val_f1_score did not improve from 0.15227
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0311 - f1_score: 0.1531 - loss: 0.0528 - precision: 0.0831 - recall: 0.9709 - val_accuracy: 0.0067 - val_f1_score: 0.1429 - val_loss: 0.0527 - val_precision: 0.0771 - val_recall: 0.9807
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0332 - f1_score: 0.1536 - loss: 0.0530 - precision: 0.0834 - recall: 0.9714
# Epoch 33 - Prediction Stats:
# Mean prediction: 0.3659
# Min prediction: 0.0126
# Max prediction: 0.5422
# Percentage of predictions > 0.5: 32.27%
# Percentage of predictions > 0.3: 68.91%
# GCN Gradients Present: False
#
# Epoch 33: val_f1_score improved from 0.15227 to 0.15317, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.0334 - f1_score: 0.1535 - loss: 0.0530 - precision: 0.0834 - recall: 0.9713 - val_accuracy: 0.0070 - val_f1_score: 0.1532 - val_loss: 0.0524 - val_precision: 0.0832 - val_recall: 0.9564
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0314 - f1_score: 0.1565 - loss: 0.0528 - precision: 0.0851 - recall: 0.9639
# Epoch 34 - Prediction Stats:
# Mean prediction: 0.3763
# Min prediction: 0.0161
# Max prediction: 0.5486
# Percentage of predictions > 0.5: 33.68%
# Percentage of predictions > 0.3: 70.85%
# GCN Gradients Present: False
#
# Epoch 34: val_f1_score did not improve from 0.15317
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0311 - f1_score: 0.1563 - loss: 0.0528 - precision: 0.0850 - recall: 0.9642 - val_accuracy: 0.0102 - val_f1_score: 0.1496 - val_loss: 0.0524 - val_precision: 0.0811 - val_recall: 0.9660
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0247 - f1_score: 0.1543 - loss: 0.0528 - precision: 0.0839 - recall: 0.9628
# Epoch 35 - Prediction Stats:
# Mean prediction: 0.3960
# Min prediction: 0.0238
# Max prediction: 0.5583
# Percentage of predictions > 0.5: 35.46%
# Percentage of predictions > 0.3: 77.45%
# GCN Gradients Present: False
#
# Epoch 35: val_f1_score did not improve from 0.15317
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0247 - f1_score: 0.1544 - loss: 0.0528 - precision: 0.0839 - recall: 0.9630 - val_accuracy: 0.0261 - val_f1_score: 0.1399 - val_loss: 0.0529 - val_precision: 0.0753 - val_recall: 0.9843
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0384 - f1_score: 0.1504 - loss: 0.0531 - precision: 0.0815 - recall: 0.9746
# Epoch 36 - Prediction Stats:
# Mean prediction: 0.3783
# Min prediction: 0.0168
# Max prediction: 0.5493
# Percentage of predictions > 0.5: 32.40%
# Percentage of predictions > 0.3: 72.54%
# GCN Gradients Present: False
#
# Epoch 36: val_f1_score did not improve from 0.15317
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0377 - f1_score: 0.1506 - loss: 0.0531 - precision: 0.0816 - recall: 0.9742 - val_accuracy: 0.0055 - val_f1_score: 0.1472 - val_loss: 0.0524 - val_precision: 0.0796 - val_recall: 0.9708
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0434 - f1_score: 0.1558 - loss: 0.0533 - precision: 0.0847 - recall: 0.9704
# Epoch 37 - Prediction Stats:
# Mean prediction: 0.3810
# Min prediction: 0.0166
# Max prediction: 0.5462
# Percentage of predictions > 0.5: 32.93%
# Percentage of predictions > 0.3: 73.35%
# GCN Gradients Present: False
#
# Epoch 37: val_f1_score did not improve from 0.15317
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0435 - f1_score: 0.1557 - loss: 0.0532 - precision: 0.0846 - recall: 0.9702 - val_accuracy: 0.0110 - val_f1_score: 0.1463 - val_loss: 0.0524 - val_precision: 0.0791 - val_recall: 0.9736
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0388 - f1_score: 0.1559 - loss: 0.0527 - precision: 0.0848 - recall: 0.9677
# Epoch 38 - Prediction Stats:
# Mean prediction: 0.3786
# Min prediction: 0.0166
# Max prediction: 0.5560
# Percentage of predictions > 0.5: 33.12%
# Percentage of predictions > 0.3: 72.84%
# GCN Gradients Present: False
#
# Epoch 38: val_f1_score did not improve from 0.15317
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0387 - f1_score: 0.1558 - loss: 0.0527 - precision: 0.0847 - recall: 0.9676 - val_accuracy: 0.0031 - val_f1_score: 0.1467 - val_loss: 0.0524 - val_precision: 0.0793 - val_recall: 0.9721
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0322 - f1_score: 0.1551 - loss: 0.0524 - precision: 0.0843 - recall: 0.9652
# Epoch 39 - Prediction Stats:
# Mean prediction: 0.3727
# Min prediction: 0.0154
# Max prediction: 0.5489
# Percentage of predictions > 0.5: 32.17%
# Percentage of predictions > 0.3: 70.32%
# GCN Gradients Present: False
#
# Epoch 39: val_f1_score did not improve from 0.15317
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0328 - f1_score: 0.1550 - loss: 0.0525 - precision: 0.0842 - recall: 0.9655 - val_accuracy: 0.0065 - val_f1_score: 0.1502 - val_loss: 0.0522 - val_precision: 0.0814 - val_recall: 0.9668
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0250 - f1_score: 0.1581 - loss: 0.0530 - precision: 0.0861 - recall: 0.9645
# Epoch 40 - Prediction Stats:
# Mean prediction: 0.3699
# Min prediction: 0.0135
# Max prediction: 0.5474
# Percentage of predictions > 0.5: 34.01%
# Percentage of predictions > 0.3: 69.18%
# GCN Gradients Present: False
#
# Epoch 40: val_f1_score did not improve from 0.15317
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0251 - f1_score: 0.1580 - loss: 0.0530 - precision: 0.0860 - recall: 0.9646 - val_accuracy: 0.0042 - val_f1_score: 0.1510 - val_loss: 0.0523 - val_precision: 0.0819 - val_recall: 0.9622
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0406 - f1_score: 0.1569 - loss: 0.0536 - precision: 0.0854 - recall: 0.9696
# Epoch 41 - Prediction Stats:
# Mean prediction: 0.3771
# Min prediction: 0.0158
# Max prediction: 0.5535
# Percentage of predictions > 0.5: 31.85%
# Percentage of predictions > 0.3: 72.46%
# GCN Gradients Present: False
#
# Epoch 41: val_f1_score did not improve from 0.15317
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0406 - f1_score: 0.1568 - loss: 0.0536 - precision: 0.0853 - recall: 0.9694 - val_accuracy: 0.0058 - val_f1_score: 0.1476 - val_loss: 0.0523 - val_precision: 0.0798 - val_recall: 0.9734
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0480 - f1_score: 0.1521 - loss: 0.0524 - precision: 0.0825 - recall: 0.9745
# Epoch 42 - Prediction Stats:
# Mean prediction: 0.3854
# Min prediction: 0.0207
# Max prediction: 0.5520
# Percentage of predictions > 0.5: 31.63%
# Percentage of predictions > 0.3: 75.82%
# GCN Gradients Present: False
#
# Epoch 42: val_f1_score did not improve from 0.15317
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0476 - f1_score: 0.1522 - loss: 0.0524 - precision: 0.0825 - recall: 0.9742 - val_accuracy: 0.0124 - val_f1_score: 0.1430 - val_loss: 0.0524 - val_precision: 0.0771 - val_recall: 0.9802
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0560 - f1_score: 0.1516 - loss: 0.0525 - precision: 0.0822 - recall: 0.9725
# Epoch 43 - Prediction Stats:
# Mean prediction: 0.3681
# Min prediction: 0.0135
# Max prediction: 0.5534
# Percentage of predictions > 0.5: 33.00%
# Percentage of predictions > 0.3: 68.25%
# GCN Gradients Present: False
#
# Epoch 43: val_f1_score did not improve from 0.15317
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0558 - f1_score: 0.1518 - loss: 0.0525 - precision: 0.0823 - recall: 0.9723 - val_accuracy: 0.0069 - val_f1_score: 0.1523 - val_loss: 0.0523 - val_precision: 0.0827 - val_recall: 0.9609
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0363 - f1_score: 0.1526 - loss: 0.0519 - precision: 0.0829 - recall: 0.9656
# Epoch 44 - Prediction Stats:
# Mean prediction: 0.3657
# Min prediction: 0.0125
# Max prediction: 0.5530
# Percentage of predictions > 0.5: 32.63%
# Percentage of predictions > 0.3: 67.47%
# GCN Gradients Present: False
#
# Epoch 44: val_f1_score improved from 0.15317 to 0.15474, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0365 - f1_score: 0.1528 - loss: 0.0519 - precision: 0.0830 - recall: 0.9658 - val_accuracy: 0.0122 - val_f1_score: 0.1547 - val_loss: 0.0522 - val_precision: 0.0842 - val_recall: 0.9550
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0540 - f1_score: 0.1590 - loss: 0.0524 - precision: 0.0867 - recall: 0.9644
# Epoch 45 - Prediction Stats:
# Mean prediction: 0.3823
# Min prediction: 0.0172
# Max prediction: 0.5614
# Percentage of predictions > 0.5: 32.81%
# Percentage of predictions > 0.3: 73.75%
# GCN Gradients Present: False
#
# Epoch 45: val_f1_score did not improve from 0.15474
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0548 - f1_score: 0.1589 - loss: 0.0524 - precision: 0.0866 - recall: 0.9645 - val_accuracy: 0.0601 - val_f1_score: 0.1462 - val_loss: 0.0523 - val_precision: 0.0790 - val_recall: 0.9765
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0610 - f1_score: 0.1549 - loss: 0.0525 - precision: 0.0842 - recall: 0.9712
# Epoch 46 - Prediction Stats:
# Mean prediction: 0.3729
# Min prediction: 0.0165
# Max prediction: 0.5584
# Percentage of predictions > 0.5: 32.99%
# Percentage of predictions > 0.3: 69.72%
# GCN Gradients Present: False
#
# Epoch 46: val_f1_score did not improve from 0.15474
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0605 - f1_score: 0.1549 - loss: 0.0526 - precision: 0.0842 - recall: 0.9710 - val_accuracy: 0.0041 - val_f1_score: 0.1498 - val_loss: 0.0522 - val_precision: 0.0812 - val_recall: 0.9661
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0394 - f1_score: 0.1532 - loss: 0.0521 - precision: 0.0832 - recall: 0.9665
# Epoch 47 - Prediction Stats:
# Mean prediction: 0.3673
# Min prediction: 0.0129
# Max prediction: 0.5551
# Percentage of predictions > 0.5: 35.69%
# Percentage of predictions > 0.3: 66.75%
# GCN Gradients Present: False
#
# Epoch 47: val_f1_score improved from 0.15474 to 0.15518, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.0399 - f1_score: 0.1533 - loss: 0.0522 - precision: 0.0832 - recall: 0.9668 - val_accuracy: 0.0082 - val_f1_score: 0.1552 - val_loss: 0.0522 - val_precision: 0.0844 - val_recall: 0.9553
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0471 - f1_score: 0.1601 - loss: 0.0527 - precision: 0.0873 - recall: 0.9605
# Epoch 48 - Prediction Stats:
# Mean prediction: 0.3813
# Min prediction: 0.0188
# Max prediction: 0.5543
# Percentage of predictions > 0.5: 32.23%
# Percentage of predictions > 0.3: 73.15%
# GCN Gradients Present: False
#
# Epoch 48: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0472 - f1_score: 0.1599 - loss: 0.0527 - precision: 0.0872 - recall: 0.9607 - val_accuracy: 0.0164 - val_f1_score: 0.1452 - val_loss: 0.0523 - val_precision: 0.0784 - val_recall: 0.9777
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0571 - f1_score: 0.1512 - loss: 0.0528 - precision: 0.0820 - recall: 0.9769
# Epoch 49 - Prediction Stats:
# Mean prediction: 0.3704
# Min prediction: 0.0128
# Max prediction: 0.5533
# Percentage of predictions > 0.5: 31.87%
# Percentage of predictions > 0.3: 69.35%
# GCN Gradients Present: False
#
# Epoch 49: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0565 - f1_score: 0.1514 - loss: 0.0528 - precision: 0.0821 - recall: 0.9766 - val_accuracy: 0.0140 - val_f1_score: 0.1523 - val_loss: 0.0524 - val_precision: 0.0827 - val_recall: 0.9607
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0787 - f1_score: 0.1562 - loss: 0.0525 - precision: 0.0849 - recall: 0.9686
# Epoch 50 - Prediction Stats:
# Mean prediction: 0.3807
# Min prediction: 0.0184
# Max prediction: 0.5625
# Percentage of predictions > 0.5: 33.47%
# Percentage of predictions > 0.3: 71.61%
# GCN Gradients Present: False
#
# Epoch 50: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0791 - f1_score: 0.1562 - loss: 0.0525 - precision: 0.0850 - recall: 0.9685 - val_accuracy: 0.0707 - val_f1_score: 0.1472 - val_loss: 0.0522 - val_precision: 0.0796 - val_recall: 0.9749
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0625 - f1_score: 0.1546 - loss: 0.0520 - precision: 0.0840 - recall: 0.9710
# Epoch 51 - Prediction Stats:
# Mean prediction: 0.3883
# Min prediction: 0.0270
# Max prediction: 0.5599
# Percentage of predictions > 0.5: 32.83%
# Percentage of predictions > 0.3: 75.40%
# GCN Gradients Present: False
#
# Epoch 51: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0623 - f1_score: 0.1547 - loss: 0.0521 - precision: 0.0841 - recall: 0.9708 - val_accuracy: 0.0168 - val_f1_score: 0.1413 - val_loss: 0.0525 - val_precision: 0.0761 - val_recall: 0.9839
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0568 - f1_score: 0.1571 - loss: 0.0536 - precision: 0.0854 - recall: 0.9739
# Epoch 52 - Prediction Stats:
# Mean prediction: 0.3764
# Min prediction: 0.0139
# Max prediction: 0.5555
# Percentage of predictions > 0.5: 32.45%
# Percentage of predictions > 0.3: 71.65%
# GCN Gradients Present: False
#
# Epoch 52: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0569 - f1_score: 0.1570 - loss: 0.0535 - precision: 0.0854 - recall: 0.9736 - val_accuracy: 0.0775 - val_f1_score: 0.1488 - val_loss: 0.0524 - val_precision: 0.0806 - val_recall: 0.9673
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0933 - f1_score: 0.1542 - loss: 0.0525 - precision: 0.0838 - recall: 0.9653
# Epoch 53 - Prediction Stats:
# Mean prediction: 0.3672
# Min prediction: 0.0138
# Max prediction: 0.5588
# Percentage of predictions > 0.5: 30.49%
# Percentage of predictions > 0.3: 68.53%
# GCN Gradients Present: False
#
# Epoch 53: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0924 - f1_score: 0.1544 - loss: 0.0525 - precision: 0.0839 - recall: 0.9655 - val_accuracy: 0.0400 - val_f1_score: 0.1528 - val_loss: 0.0520 - val_precision: 0.0830 - val_recall: 0.9608
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0672 - f1_score: 0.1574 - loss: 0.0516 - precision: 0.0857 - recall: 0.9658
# Epoch 54 - Prediction Stats:
# Mean prediction: 0.3778
# Min prediction: 0.0192
# Max prediction: 0.5588
# Percentage of predictions > 0.5: 32.47%
# Percentage of predictions > 0.3: 70.96%
# GCN Gradients Present: False
#
# Epoch 54: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0672 - f1_score: 0.1574 - loss: 0.0517 - precision: 0.0857 - recall: 0.9659 - val_accuracy: 0.0185 - val_f1_score: 0.1485 - val_loss: 0.0520 - val_precision: 0.0804 - val_recall: 0.9722
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0506 - f1_score: 0.1554 - loss: 0.0530 - precision: 0.0845 - recall: 0.9704
# Epoch 55 - Prediction Stats:
# Mean prediction: 0.3718
# Min prediction: 0.0150
# Max prediction: 0.5519
# Percentage of predictions > 0.5: 31.81%
# Percentage of predictions > 0.3: 69.75%
# GCN Gradients Present: False
#
# Epoch 55: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0502 - f1_score: 0.1555 - loss: 0.0530 - precision: 0.0846 - recall: 0.9702 - val_accuracy: 0.0126 - val_f1_score: 0.1512 - val_loss: 0.0522 - val_precision: 0.0820 - val_recall: 0.9654
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0572 - f1_score: 0.1544 - loss: 0.0521 - precision: 0.0839 - recall: 0.9711
# Epoch 56 - Prediction Stats:
# Mean prediction: 0.3626
# Min prediction: 0.0113
# Max prediction: 0.5421
# Percentage of predictions > 0.5: 29.84%
# Percentage of predictions > 0.3: 67.93%
# GCN Gradients Present: False
#
# Epoch 56: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0572 - f1_score: 0.1545 - loss: 0.0521 - precision: 0.0840 - recall: 0.9711 - val_accuracy: 0.0359 - val_f1_score: 0.1548 - val_loss: 0.0519 - val_precision: 0.0842 - val_recall: 0.9591
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0754 - f1_score: 0.1585 - loss: 0.0521 - precision: 0.0863 - recall: 0.9699
# Epoch 57 - Prediction Stats:
# Mean prediction: 0.3777
# Min prediction: 0.0185
# Max prediction: 0.5526
# Percentage of predictions > 0.5: 31.73%
# Percentage of predictions > 0.3: 71.41%
# GCN Gradients Present: False
#
# Epoch 57: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0752 - f1_score: 0.1585 - loss: 0.0522 - precision: 0.0863 - recall: 0.9697 - val_accuracy: 0.0694 - val_f1_score: 0.1492 - val_loss: 0.0519 - val_precision: 0.0808 - val_recall: 0.9715
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0797 - f1_score: 0.1550 - loss: 0.0517 - precision: 0.0842 - recall: 0.9741
# Epoch 58 - Prediction Stats:
# Mean prediction: 0.3712
# Min prediction: 0.0216
# Max prediction: 0.5604
# Percentage of predictions > 0.5: 30.29%
# Percentage of predictions > 0.3: 69.55%
# GCN Gradients Present: False
#
# Epoch 58: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0798 - f1_score: 0.1550 - loss: 0.0517 - precision: 0.0842 - recall: 0.9739 - val_accuracy: 0.0694 - val_f1_score: 0.1506 - val_loss: 0.0518 - val_precision: 0.0817 - val_recall: 0.9664
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0950 - f1_score: 0.1576 - loss: 0.0522 - precision: 0.0858 - recall: 0.9694
# Epoch 59 - Prediction Stats:
# Mean prediction: 0.3776
# Min prediction: 0.0194
# Max prediction: 0.5633
# Percentage of predictions > 0.5: 30.51%
# Percentage of predictions > 0.3: 71.55%
# GCN Gradients Present: False
#
# Epoch 59: val_f1_score did not improve from 0.15518
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0958 - f1_score: 0.1577 - loss: 0.0522 - precision: 0.0858 - recall: 0.9693 - val_accuracy: 0.1336 - val_f1_score: 0.1487 - val_loss: 0.0518 - val_precision: 0.0805 - val_recall: 0.9729
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0825 - f1_score: 0.1567 - loss: 0.0523 - precision: 0.0852 - recall: 0.9718
# Epoch 60 - Prediction Stats:
# Mean prediction: 0.3626
# Min prediction: 0.0154
# Max prediction: 0.5571
# Percentage of predictions > 0.5: 29.97%
# Percentage of predictions > 0.3: 67.65%
# GCN Gradients Present: False
#
# Epoch 60: val_f1_score improved from 0.15518 to 0.15525, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0813 - f1_score: 0.1567 - loss: 0.0523 - precision: 0.0853 - recall: 0.9716 - val_accuracy: 0.0477 - val_f1_score: 0.1553 - val_loss: 0.0515 - val_precision: 0.0845 - val_recall: 0.9599
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0882 - f1_score: 0.1573 - loss: 0.0522 - precision: 0.0856 - recall: 0.9697
# Epoch 61 - Prediction Stats:
# Mean prediction: 0.3552
# Min prediction: 0.0119
# Max prediction: 0.5673
# Percentage of predictions > 0.5: 28.60%
# Percentage of predictions > 0.3: 65.21%
# GCN Gradients Present: False
#
# Epoch 61: val_f1_score improved from 0.15525 to 0.16036, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.0891 - f1_score: 0.1573 - loss: 0.0522 - precision: 0.0856 - recall: 0.9699 - val_accuracy: 0.1008 - val_f1_score: 0.1604 - val_loss: 0.0516 - val_precision: 0.0876 - val_recall: 0.9479
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0804 - f1_score: 0.1605 - loss: 0.0513 - precision: 0.0875 - recall: 0.9645
# Epoch 62 - Prediction Stats:
# Mean prediction: 0.3759
# Min prediction: 0.0200
# Max prediction: 0.5716
# Percentage of predictions > 0.5: 31.89%
# Percentage of predictions > 0.3: 70.80%
# GCN Gradients Present: False
#
# Epoch 62: val_f1_score did not improve from 0.16036
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0804 - f1_score: 0.1603 - loss: 0.0513 - precision: 0.0874 - recall: 0.9648 - val_accuracy: 0.1986 - val_f1_score: 0.1509 - val_loss: 0.0513 - val_precision: 0.0818 - val_recall: 0.9719
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1304 - f1_score: 0.1608 - loss: 0.0513 - precision: 0.0877 - recall: 0.9683
# Epoch 63 - Prediction Stats:
# Mean prediction: 0.3735
# Min prediction: 0.0171
# Max prediction: 0.5713
# Percentage of predictions > 0.5: 29.00%
# Percentage of predictions > 0.3: 70.26%
# GCN Gradients Present: False
#
# Epoch 63: val_f1_score did not improve from 0.16036
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1305 - f1_score: 0.1608 - loss: 0.0513 - precision: 0.0877 - recall: 0.9683 - val_accuracy: 0.2883 - val_f1_score: 0.1536 - val_loss: 0.0510 - val_precision: 0.0834 - val_recall: 0.9679
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0950 - f1_score: 0.1586 - loss: 0.0515 - precision: 0.0863 - recall: 0.9725
# Epoch 64 - Prediction Stats:
# Mean prediction: 0.3601
# Min prediction: 0.0129
# Max prediction: 0.6046
# Percentage of predictions > 0.5: 29.30%
# Percentage of predictions > 0.3: 66.10%
# GCN Gradients Present: False
#
# Epoch 64: val_f1_score improved from 0.16036 to 0.16150, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0942 - f1_score: 0.1587 - loss: 0.0515 - precision: 0.0864 - recall: 0.9724 - val_accuracy: 0.1250 - val_f1_score: 0.1615 - val_loss: 0.0509 - val_precision: 0.0882 - val_recall: 0.9563
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1123 - f1_score: 0.1607 - loss: 0.0509 - precision: 0.0877 - recall: 0.9677
# Epoch 65 - Prediction Stats:
# Mean prediction: 0.3733
# Min prediction: 0.0206
# Max prediction: 0.5945
# Percentage of predictions > 0.5: 29.03%
# Percentage of predictions > 0.3: 71.04%
# GCN Gradients Present: False
#
# Epoch 65: val_f1_score did not improve from 0.16150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1122 - f1_score: 0.1609 - loss: 0.0509 - precision: 0.0878 - recall: 0.9677 - val_accuracy: 0.0961 - val_f1_score: 0.1555 - val_loss: 0.0507 - val_precision: 0.0845 - val_recall: 0.9678
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0472 - f1_score: 0.1579 - loss: 0.0504 - precision: 0.0860 - recall: 0.9716
# Epoch 66 - Prediction Stats:
# Mean prediction: 0.3645
# Min prediction: 0.0137
# Max prediction: 0.6236
# Percentage of predictions > 0.5: 29.73%
# Percentage of predictions > 0.3: 67.14%
# GCN Gradients Present: False
#
# Epoch 66: val_f1_score did not improve from 0.16150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.0479 - f1_score: 0.1582 - loss: 0.0505 - precision: 0.0861 - recall: 0.9714 - val_accuracy: 0.2081 - val_f1_score: 0.1614 - val_loss: 0.0506 - val_precision: 0.0881 - val_recall: 0.9579
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1248 - f1_score: 0.1637 - loss: 0.0514 - precision: 0.0894 - recall: 0.9677
# Epoch 67 - Prediction Stats:
# Mean prediction: 0.3615
# Min prediction: 0.0138
# Max prediction: 0.6485
# Percentage of predictions > 0.5: 29.37%
# Percentage of predictions > 0.3: 66.19%
# GCN Gradients Present: False
#
# Epoch 67: val_f1_score improved from 0.16150 to 0.16265, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1242 - f1_score: 0.1637 - loss: 0.0513 - precision: 0.0894 - recall: 0.9678 - val_accuracy: 0.2003 - val_f1_score: 0.1626 - val_loss: 0.0503 - val_precision: 0.0889 - val_recall: 0.9546
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1004 - f1_score: 0.1653 - loss: 0.0505 - precision: 0.0904 - recall: 0.9661
# Epoch 68 - Prediction Stats:
# Mean prediction: 0.3669
# Min prediction: 0.0168
# Max prediction: 0.6698
# Percentage of predictions > 0.5: 29.44%
# Percentage of predictions > 0.3: 67.50%
# GCN Gradients Present: False
#
# Epoch 68: val_f1_score did not improve from 0.16265
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0999 - f1_score: 0.1653 - loss: 0.0505 - precision: 0.0904 - recall: 0.9661 - val_accuracy: 0.1084 - val_f1_score: 0.1625 - val_loss: 0.0502 - val_precision: 0.0888 - val_recall: 0.9583
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0831 - f1_score: 0.1661 - loss: 0.0508 - precision: 0.0909 - recall: 0.9650
# Epoch 69 - Prediction Stats:
# Mean prediction: 0.3643
# Min prediction: 0.0145
# Max prediction: 0.6706
# Percentage of predictions > 0.5: 30.04%
# Percentage of predictions > 0.3: 65.88%
# GCN Gradients Present: False
#
# Epoch 69: val_f1_score improved from 0.16265 to 0.16268, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.0837 - f1_score: 0.1661 - loss: 0.0508 - precision: 0.0909 - recall: 0.9651 - val_accuracy: 0.1056 - val_f1_score: 0.1627 - val_loss: 0.0500 - val_precision: 0.0889 - val_recall: 0.9599
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0894 - f1_score: 0.1656 - loss: 0.0505 - precision: 0.0905 - recall: 0.9679
# Epoch 70 - Prediction Stats:
# Mean prediction: 0.3608
# Min prediction: 0.0147
# Max prediction: 0.6636
# Percentage of predictions > 0.5: 27.36%
# Percentage of predictions > 0.3: 66.39%
# GCN Gradients Present: False
#
# Epoch 70: val_f1_score improved from 0.16268 to 0.16441, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.0892 - f1_score: 0.1657 - loss: 0.0504 - precision: 0.0906 - recall: 0.9680 - val_accuracy: 0.1595 - val_f1_score: 0.1644 - val_loss: 0.0499 - val_precision: 0.0900 - val_recall: 0.9547
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0975 - f1_score: 0.1672 - loss: 0.0503 - precision: 0.0915 - recall: 0.9674
# Epoch 71 - Prediction Stats:
# Mean prediction: 0.3694
# Min prediction: 0.0224
# Max prediction: 0.6738
# Percentage of predictions > 0.5: 28.09%
# Percentage of predictions > 0.3: 68.56%
# GCN Gradients Present: False
#
# Epoch 71: val_f1_score did not improve from 0.16441
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.0978 - f1_score: 0.1672 - loss: 0.0503 - precision: 0.0915 - recall: 0.9674 - val_accuracy: 0.1743 - val_f1_score: 0.1605 - val_loss: 0.0497 - val_precision: 0.0875 - val_recall: 0.9637
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0837 - f1_score: 0.1669 - loss: 0.0494 - precision: 0.0913 - recall: 0.9715
# Epoch 72 - Prediction Stats:
# Mean prediction: 0.3524
# Min prediction: 0.0131
# Max prediction: 0.6768
# Percentage of predictions > 0.5: 26.82%
# Percentage of predictions > 0.3: 64.43%
# GCN Gradients Present: False
#
# Epoch 72: val_f1_score improved from 0.16441 to 0.16965, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.0837 - f1_score: 0.1670 - loss: 0.0494 - precision: 0.0914 - recall: 0.9714 - val_accuracy: 0.1426 - val_f1_score: 0.1696 - val_loss: 0.0495 - val_precision: 0.0932 - val_recall: 0.9488
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0851 - f1_score: 0.1727 - loss: 0.0501 - precision: 0.0948 - recall: 0.9688
# Epoch 73 - Prediction Stats:
# Mean prediction: 0.3522
# Min prediction: 0.0123
# Max prediction: 0.6908
# Percentage of predictions > 0.5: 26.04%
# Percentage of predictions > 0.3: 64.16%
# GCN Gradients Present: False
#
# Epoch 73: val_f1_score improved from 0.16965 to 0.16980, saving model to best_model.keras
# ...
# GCN Gradients Present: False
#
# Epoch 78: val_f1_score improved from 0.16980 to 0.17408, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - accuracy: 0.1226 - f1_score: 0.1662 - loss: 0.0484 - precision: 0.0909 - recall: 0.9687 - val_accuracy: 0.3611 - val_f1_score: 0.1741 - val_loss: 0.0484 - val_precision: 0.0958 - val_recall: 0.9483
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1441 - f1_score: 0.1762 - loss: 0.0487 - precision: 0.0970 - recall: 0.9668
# Epoch 79 - Prediction Stats:
# Mean prediction: 0.3508
# Min prediction: 0.0156
# Max prediction: 0.6943
# Percentage of predictions > 0.5: 25.03%
# Percentage of predictions > 0.3: 63.47%
# GCN Gradients Present: False
#
# Epoch 79: val_f1_score did not improve from 0.17408
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1442 - f1_score: 0.1761 - loss: 0.0487 - precision: 0.0969 - recall: 0.9668 - val_accuracy: 0.3213 - val_f1_score: 0.1735 - val_loss: 0.0480 - val_precision: 0.0955 - val_recall: 0.9501
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1262 - f1_score: 0.1725 - loss: 0.0481 - precision: 0.0947 - recall: 0.9667
# Epoch 80 - Prediction Stats:
# Mean prediction: 0.3563
# Min prediction: 0.0149
# Max prediction: 0.7083
# Percentage of predictions > 0.5: 27.06%
# Percentage of predictions > 0.3: 63.70%
# GCN Gradients Present: False
#
# Epoch 80: val_f1_score did not improve from 0.17408
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1272 - f1_score: 0.1727 - loss: 0.0481 - precision: 0.0948 - recall: 0.9667 - val_accuracy: 0.4259 - val_f1_score: 0.1739 - val_loss: 0.0479 - val_precision: 0.0957 - val_recall: 0.9522
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1610 - f1_score: 0.1742 - loss: 0.0477 - precision: 0.0957 - recall: 0.9672
# Epoch 81 - Prediction Stats:
# Mean prediction: 0.3546
# Min prediction: 0.0227
# Max prediction: 0.7062
# Percentage of predictions > 0.5: 25.79%
# Percentage of predictions > 0.3: 64.68%
# GCN Gradients Present: False
#
# Epoch 81: val_f1_score did not improve from 0.17408
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1604 - f1_score: 0.1743 - loss: 0.0477 - precision: 0.0958 - recall: 0.9672 - val_accuracy: 0.3738 - val_f1_score: 0.1735 - val_loss: 0.0478 - val_precision: 0.0954 - val_recall: 0.9542
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1723 - f1_score: 0.1776 - loss: 0.0484 - precision: 0.0978 - recall: 0.9679
# Epoch 82 - Prediction Stats:
# Mean prediction: 0.3394
# Min prediction: 0.0104
# Max prediction: 0.7105
# Percentage of predictions > 0.5: 23.24%
# Percentage of predictions > 0.3: 60.90%
# GCN Gradients Present: False
#
# Epoch 82: val_f1_score improved from 0.17408 to 0.17929, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1713 - f1_score: 0.1774 - loss: 0.0483 - precision: 0.0977 - recall: 0.9680 - val_accuracy: 0.3343 - val_f1_score: 0.1793 - val_loss: 0.0475 - val_precision: 0.0991 - val_recall: 0.9437
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1380 - f1_score: 0.1823 - loss: 0.0488 - precision: 0.1007 - recall: 0.9658
# Epoch 83 - Prediction Stats:
# Mean prediction: 0.3457
# Min prediction: 0.0148
# Max prediction: 0.6954
# Percentage of predictions > 0.5: 21.95%
# Percentage of predictions > 0.3: 62.80%
# GCN Gradients Present: False
#
# Epoch 83: val_f1_score did not improve from 0.17929
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1383 - f1_score: 0.1820 - loss: 0.0487 - precision: 0.1005 - recall: 0.9658 - val_accuracy: 0.3945 - val_f1_score: 0.1782 - val_loss: 0.0470 - val_precision: 0.0983 - val_recall: 0.9491
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1447 - f1_score: 0.1782 - loss: 0.0472 - precision: 0.0982 - recall: 0.9659
# Epoch 84 - Prediction Stats:
# Mean prediction: 0.3462
# Min prediction: 0.0136
# Max prediction: 0.7255
# Percentage of predictions > 0.5: 23.73%
# Percentage of predictions > 0.3: 62.14%
# GCN Gradients Present: False
#
# Epoch 84: val_f1_score did not improve from 0.17929
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1449 - f1_score: 0.1782 - loss: 0.0472 - precision: 0.0982 - recall: 0.9660 - val_accuracy: 0.4057 - val_f1_score: 0.1777 - val_loss: 0.0475 - val_precision: 0.0981 - val_recall: 0.9443
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1575 - f1_score: 0.1832 - loss: 0.0476 - precision: 0.1012 - recall: 0.9655
# Epoch 85 - Prediction Stats:
# Mean prediction: 0.3220
# Min prediction: 0.0123
# Max prediction: 0.6905
# Percentage of predictions > 0.5: 20.06%
# Percentage of predictions > 0.3: 55.75%
# GCN Gradients Present: False
#
# Epoch 85: val_f1_score improved from 0.17929 to 0.18927, saving model to best_model.keras
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1583 - f1_score: 0.1828 - loss: 0.0476 - precision: 0.1009 - recall: 0.9657 - val_accuracy: 0.4523 - val_f1_score: 0.1893 - val_loss: 0.0473 - val_precision: 0.1054 - val_recall: 0.9265
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1714 - f1_score: 0.1829 - loss: 0.0465 - precision: 0.1011 - recall: 0.9609
# Epoch 86 - Prediction Stats:
# Mean prediction: 0.3635
# Min prediction: 0.0240
# Max prediction: 0.6863
# Percentage of predictions > 0.5: 25.07%
# Percentage of predictions > 0.3: 67.36%
# GCN Gradients Present: False
#
# Epoch 86: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1709 - f1_score: 0.1828 - loss: 0.0465 - precision: 0.1010 - recall: 0.9611 - val_accuracy: 0.3945 - val_f1_score: 0.1678 - val_loss: 0.0469 - val_precision: 0.0919 - val_recall: 0.9679
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1589 - f1_score: 0.1780 - loss: 0.0470 - precision: 0.0980 - recall: 0.9697
# Epoch 87 - Prediction Stats:
# Mean prediction: 0.3522
# Min prediction: 0.0212
# Max prediction: 0.7190
# Percentage of predictions > 0.5: 21.95%
# Percentage of predictions > 0.3: 65.36%
# GCN Gradients Present: False
#
# Epoch 87: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1580 - f1_score: 0.1781 - loss: 0.0470 - precision: 0.0981 - recall: 0.9694 - val_accuracy: 0.3356 - val_f1_score: 0.1742 - val_loss: 0.0463 - val_precision: 0.0957 - val_recall: 0.9633
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1403 - f1_score: 0.1768 - loss: 0.0471 - precision: 0.0972 - recall: 0.9708
# Epoch 88 - Prediction Stats:
# Mean prediction: 0.3462
# Min prediction: 0.0191
# Max prediction: 0.7128
# Percentage of predictions > 0.5: 21.95%
# Percentage of predictions > 0.3: 62.98%
# GCN Gradients Present: False
#
# Epoch 88: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1417 - f1_score: 0.1770 - loss: 0.0470 - precision: 0.0974 - recall: 0.9706 - val_accuracy: 0.4155 - val_f1_score: 0.1780 - val_loss: 0.0462 - val_precision: 0.0982 - val_recall: 0.9563
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1624 - f1_score: 0.1844 - loss: 0.0467 - precision: 0.1020 - recall: 0.9667
# Epoch 89 - Prediction Stats:
# Mean prediction: 0.3521
# Min prediction: 0.0179
# Max prediction: 0.7148
# Percentage of predictions > 0.5: 22.66%
# Percentage of predictions > 0.3: 64.88%
# GCN Gradients Present: False
#
# Epoch 89: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1615 - f1_score: 0.1843 - loss: 0.0467 - precision: 0.1019 - recall: 0.9666 - val_accuracy: 0.4097 - val_f1_score: 0.1736 - val_loss: 0.0462 - val_precision: 0.0954 - val_recall: 0.9631
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1599 - f1_score: 0.1763 - loss: 0.0464 - precision: 0.0970 - recall: 0.9738
# Epoch 90 - Prediction Stats:
# Mean prediction: 0.3360
# Min prediction: 0.0144
# Max prediction: 0.7033
# Percentage of predictions > 0.5: 21.05%
# Percentage of predictions > 0.3: 59.92%
# GCN Gradients Present: False
#
# Epoch 90: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1597 - f1_score: 0.1766 - loss: 0.0464 - precision: 0.0971 - recall: 0.9736 - val_accuracy: 0.3723 - val_f1_score: 0.1830 - val_loss: 0.0461 - val_precision: 0.1013 - val_recall: 0.9496
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1511 - f1_score: 0.1873 - loss: 0.0468 - precision: 0.1037 - recall: 0.9646
# Epoch 91 - Prediction Stats:
# Mean prediction: 0.3296
# Min prediction: 0.0133
# Max prediction: 0.7029
# Percentage of predictions > 0.5: 19.87%
# Percentage of predictions > 0.3: 58.04%
# GCN Gradients Present: False
#
# Epoch 91: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1506 - f1_score: 0.1870 - loss: 0.0467 - precision: 0.1035 - recall: 0.9648 - val_accuracy: 0.2258 - val_f1_score: 0.1875 - val_loss: 0.0461 - val_precision: 0.1041 - val_recall: 0.9433
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1261 - f1_score: 0.1862 - loss: 0.0464 - precision: 0.1031 - recall: 0.9627
# Epoch 92 - Prediction Stats:
# Mean prediction: 0.3327
# Min prediction: 0.0122
# Max prediction: 0.7145
# Percentage of predictions > 0.5: 21.35%
# Percentage of predictions > 0.3: 58.27%
# GCN Gradients Present: False
#
# Epoch 92: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1262 - f1_score: 0.1859 - loss: 0.0464 - precision: 0.1029 - recall: 0.9629 - val_accuracy: 0.3579 - val_f1_score: 0.1863 - val_loss: 0.0462 - val_precision: 0.1034 - val_recall: 0.9437
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1478 - f1_score: 0.1857 - loss: 0.0455 - precision: 0.1028 - recall: 0.9647
# Epoch 93 - Prediction Stats:
# Mean prediction: 0.3520
# Min prediction: 0.0178
# Max prediction: 0.7157
# Percentage of predictions > 0.5: 22.19%
# Percentage of predictions > 0.3: 63.62%
# GCN Gradients Present: False
#
# Epoch 93: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1480 - f1_score: 0.1857 - loss: 0.0455 - precision: 0.1027 - recall: 0.9648 - val_accuracy: 0.3899 - val_f1_score: 0.1770 - val_loss: 0.0457 - val_precision: 0.0975 - val_recall: 0.9614
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1538 - f1_score: 0.1860 - loss: 0.0457 - precision: 0.1029 - recall: 0.9687
# Epoch 94 - Prediction Stats:
# Mean prediction: 0.3444
# Min prediction: 0.0142
# Max prediction: 0.7256
# Percentage of predictions > 0.5: 22.90%
# Percentage of predictions > 0.3: 61.22%
# GCN Gradients Present: False
#
# Epoch 94: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1535 - f1_score: 0.1859 - loss: 0.0458 - precision: 0.1028 - recall: 0.9684 - val_accuracy: 0.3931 - val_f1_score: 0.1807 - val_loss: 0.0459 - val_precision: 0.0998 - val_recall: 0.9540
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1545 - f1_score: 0.1783 - loss: 0.0460 - precision: 0.0982 - recall: 0.9707
# Epoch 95 - Prediction Stats:
# Mean prediction: 0.3320
# Min prediction: 0.0108
# Max prediction: 0.7242
# Percentage of predictions > 0.5: 20.52%
# Percentage of predictions > 0.3: 58.93%
# GCN Gradients Present: False
#
# Epoch 95: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1536 - f1_score: 0.1786 - loss: 0.0460 - precision: 0.0983 - recall: 0.9706 - val_accuracy: 0.3467 - val_f1_score: 0.1872 - val_loss: 0.0456 - val_precision: 0.1038 - val_recall: 0.9499
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1343 - f1_score: 0.1843 - loss: 0.0462 - precision: 0.1019 - recall: 0.9655
# Epoch 96 - Prediction Stats:
# Mean prediction: 0.3430
# Min prediction: 0.0127
# Max prediction: 0.7151
# Percentage of predictions > 0.5: 22.77%
# Percentage of predictions > 0.3: 60.98%
# GCN Gradients Present: False
#
# Epoch 96: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1343 - f1_score: 0.1843 - loss: 0.0462 - precision: 0.1019 - recall: 0.9657 - val_accuracy: 0.2702 - val_f1_score: 0.1823 - val_loss: 0.0456 - val_precision: 0.1008 - val_recall: 0.9536
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1330 - f1_score: 0.1867 - loss: 0.0454 - precision: 0.1034 - recall: 0.9638
# Epoch 97 - Prediction Stats:
# Mean prediction: 0.3467
# Min prediction: 0.0129
# Max prediction: 0.7122
# Percentage of predictions > 0.5: 23.45%
# Percentage of predictions > 0.3: 61.41%
# GCN Gradients Present: False
#
# Epoch 97: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1331 - f1_score: 0.1867 - loss: 0.0454 - precision: 0.1034 - recall: 0.9639 - val_accuracy: 0.3691 - val_f1_score: 0.1808 - val_loss: 0.0453 - val_precision: 0.0998 - val_recall: 0.9592
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1570 - f1_score: 0.1889 - loss: 0.0449 - precision: 0.1046 - recall: 0.9694
# Epoch 98 - Prediction Stats:
# Mean prediction: 0.3293
# Min prediction: 0.0103
# Max prediction: 0.7017
# Percentage of predictions > 0.5: 19.05%
# Percentage of predictions > 0.3: 58.57%
# GCN Gradients Present: False
#
# Epoch 98: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - accuracy: 0.1569 - f1_score: 0.1887 - loss: 0.0449 - precision: 0.1046 - recall: 0.9693 - val_accuracy: 0.4110 - val_f1_score: 0.1892 - val_loss: 0.0452 - val_precision: 0.1051 - val_recall: 0.9502
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1568 - f1_score: 0.1889 - loss: 0.0448 - precision: 0.1047 - recall: 0.9647
# Epoch 99 - Prediction Stats:
# Mean prediction: 0.3569
# Min prediction: 0.0167
# Max prediction: 0.6911
# Percentage of predictions > 0.5: 21.66%
# Percentage of predictions > 0.3: 65.54%
# GCN Gradients Present: False
#
# Epoch 99: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1563 - f1_score: 0.1890 - loss: 0.0448 - precision: 0.1047 - recall: 0.9647 - val_accuracy: 0.3680 - val_f1_score: 0.1738 - val_loss: 0.0451 - val_precision: 0.0955 - val_recall: 0.9684
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1340 - f1_score: 0.1851 - loss: 0.0460 - precision: 0.1023 - recall: 0.9724
# Epoch 100 - Prediction Stats:
# Mean prediction: 0.3286
# Min prediction: 0.0095
# Max prediction: 0.6940
# Percentage of predictions > 0.5: 19.30%
# Percentage of predictions > 0.3: 58.85%
# GCN Gradients Present: False
#
# Epoch 100: val_f1_score did not improve from 0.18927
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.1350 - f1_score: 0.1852 - loss: 0.0459 - precision: 0.1024 - recall: 0.9720 - val_accuracy: 0.3503 - val_f1_score: 0.1880 - val_loss: 0.0450 - val_precision: 0.1043 - val_recall: 0.9520
# Restoring model weights from the end of the best epoch: 85.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1434/1626457582.py in <module>
#     413 val_labels = labels[val_indices]
#     414
# --> 415 val_predictions = model.predict(val_spectrograms)
#     416 val_predictions_probs = smooth_predictions(val_predictions)
#     417 val_predictions_filtered = filter_short_notes(val_predictions_probs)
#
# ~/.local/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /tmp/ipykernel_1434/1626457582.py in call(self, inputs, training)
#     270     def call(self, inputs, training=False):
#     271         spectrogram = inputs
# --> 272         cnn_lstm_outputs = self.cnn_lstm(spectrogram)
#     273         x = cnn_lstm_outputs['cnn_lstm_features']
#     274         cnn_lstm_pred = cnn_lstm_outputs['cnn_lstm_pred']
#
# ValueError: Exception encountered when calling CRGCN.call().
#
# as_list() is not defined on an unknown TensorShape.
#
# Arguments received by CRGCN.call():
#   • inputs=tf.Tensor(shape=<unknown>, dtype=float32)
#   • training=False
